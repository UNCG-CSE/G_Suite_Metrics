# %%
# %matplotlib inline
import pandas as pd
import numpy as np
df = pd.read_csv('Gcalender.csv', header=None)
df.columns = ['Date','Metric','Value']

# %%
df.dtypes
df['Date'] = pd.to_datetime(df.Date, utc=True)

# %%
# Out:
#                             Date  \
# 0      2015-03-23 04:00:00+00:00
# 1      2015-03-23 04:00:00+00:00
# 2      2015-03-23 04:00:00+00:00
# 3      2015-03-23 04:00:00+00:00
# 4      2015-03-23 04:00:00+00:00
# 5      2015-03-23 04:00:00+00:00
# 6      2015-03-23 04:00:00+00:00
# 7      2015-03-23 04:00:00+00:00
# 8      2015-03-23 04:00:00+00:00
# 9      2015-03-23 04:00:00+00:00
# 10     2015-03-23 04:00:00+00:00
# 11     2015-03-23 04:00:00+00:00
# 12     2015-03-23 04:00:00+00:00
# 13     2015-03-23 04:00:00+00:00
# 14     2015-03-23 04:00:00+00:00
# 15     2015-03-23 04:00:00+00:00
# 16     2015-03-23 04:00:00+00:00
# 17     2015-03-23 04:00:00+00:00
# 18     2015-03-23 04:00:00+00:00
# 19     2015-03-23 04:00:00+00:00
# 784    2015-03-30 04:00:00+00:00
# 785    2015-03-30 04:00:00+00:00
# 786    2015-03-30 04:00:00+00:00
# 787    2015-03-30 04:00:00+00:00
# 788    2015-03-30 04:00:00+00:00
# 789    2015-03-30 04:00:00+00:00
# 790    2015-03-30 04:00:00+00:00
# ...
