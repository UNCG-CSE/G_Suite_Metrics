# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import datetime
df = pd.read_csv('Gcalender.csv')
df.head()
# Out:
#                         time                             metric_name  \
# 0  2015-03-23 00:00:00-04:00   google.calendar:num_1day_active_users
# 1  2015-03-23 00:00:00-04:00  google.calendar:num_30day_active_users
# 2  2015-03-23 00:00:00-04:00   google.calendar:num_7day_active_users
# 3  2015-03-24 00:00:00-04:00   google.calendar:num_1day_active_users
# 4  2015-03-24 00:00:00-04:00  google.calendar:num_30day_active_users
#
#    metric_value
# 0          2197
# 1          6252
# 2          3953
# 3          2174
# 4          6324

# %%
df['time'] =  pd.to_datetime(df['time'], format='%Y%m%d %H:%M:%S.%f', utc=True)

# %%
df.dtypes
# Out:
# time            datetime64[ns, UTC]
# metric_name                  object
# metric_value                  int64
# dtype: object

# %%
dailyDf = df[df['metric_name'].str.match('google.calendar:num_1day_active_users')]
dailyDf.head()
# Out:
#                         time                            metric_name  \
# 0  2015-03-23 04:00:00+00:00  google.calendar:num_1day_active_users
# 3  2015-03-24 04:00:00+00:00  google.calendar:num_1day_active_users
# 6  2015-03-25 04:00:00+00:00  google.calendar:num_1day_active_users
# 9  2015-03-26 04:00:00+00:00  google.calendar:num_1day_active_users
# 12 2015-03-27 04:00:00+00:00  google.calendar:num_1day_active_users
#
#     metric_value
# 0           2197
# 3           2174
# 6           2190
# 9           2139
# 12          1750

# %%
dailyDf.dtypes
# Out:
# time            datetime64[ns, UTC]
# metric_name                  object
# metric_value                  int64
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(dailyDf.time,
        dailyDf['metric_value'], '-o',
        color='purple')
# Out:
# /Users/jackiecuong/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
dailyDf.mean()
# Out:
# metric_value    1649.214606
# dtype: float64

# %%
dailyDf.median()
# Out:
# metric_value    1745.0
# dtype: float64

# %%
df.iloc[dailyDf[['metric_value']].idxmax() ]
# Out:
#                           time                            metric_name  \
# 3354 2018-05-04 04:00:00+00:00  google.calendar:num_1day_active_users
#
#       metric_value
# 3354         10979

# %%
plt.hist(dailyDf['metric_value'], bins=25,ec='black')
plt.xlabel('Daily Users')
plt.show()

# %%
dailyDf.sort_values(by=['metric_value'], ascending=False)
# Out:
#                           time                            metric_name  \
# 3354 2018-05-04 04:00:00+00:00  google.calendar:num_1day_active_users
# 4674 2019-08-15 04:00:00+00:00  google.calendar:num_1day_active_users
# 4665 2019-08-12 04:00:00+00:00  google.calendar:num_1day_active_users
# 4668 2019-08-13 04:00:00+00:00  google.calendar:num_1day_active_users
# 4671 2019-08-14 04:00:00+00:00  google.calendar:num_1day_active_users
# 4677 2019-08-16 04:00:00+00:00  google.calendar:num_1day_active_users
# 4644 2019-08-05 04:00:00+00:00  google.calendar:num_1day_active_users
# 4647 2019-08-06 04:00:00+00:00  google.calendar:num_1day_active_users
# 4650 2019-08-07 04:00:00+00:00  google.calendar:num_1day_active_users
# 4653 2019-08-08 04:00:00+00:00  google.calendar:num_1day_active_users
# 4593 2019-07-15 04:00:00+00:00  google.calendar:num_1day_active_users
# 4629 2019-07-30 04:00:00+00:00  google.calendar:num_1day_active_users
# ...

# %%
newDaily = dailyDf.drop([3354])
newDaily.sort_values(by=['metric_value'], ascending=False)
# Out:
#                           time                            metric_name  \
# 4674 2019-08-15 04:00:00+00:00  google.calendar:num_1day_active_users
# 4665 2019-08-12 04:00:00+00:00  google.calendar:num_1day_active_users
# 4668 2019-08-13 04:00:00+00:00  google.calendar:num_1day_active_users
# 4671 2019-08-14 04:00:00+00:00  google.calendar:num_1day_active_users
# 4677 2019-08-16 04:00:00+00:00  google.calendar:num_1day_active_users
# 4644 2019-08-05 04:00:00+00:00  google.calendar:num_1day_active_users
# 4647 2019-08-06 04:00:00+00:00  google.calendar:num_1day_active_users
# 4650 2019-08-07 04:00:00+00:00  google.calendar:num_1day_active_users
# 4653 2019-08-08 04:00:00+00:00  google.calendar:num_1day_active_users
# 4593 2019-07-15 04:00:00+00:00  google.calendar:num_1day_active_users
# 4629 2019-07-30 04:00:00+00:00  google.calendar:num_1day_active_users
# 4626 2019-07-29 04:00:00+00:00  google.calendar:num_1day_active_users
# ...

# %%
newDaily.describe()
# Out:
#        metric_value
# count   1560.000000
# mean    1643.233974
# std      684.850644
# min      268.000000
# 25%     1017.000000
# 50%     1745.000000
# 75%     2236.250000
# max     3658.000000

# %%
plt.hist(newDaily['metric_value'], bins=20,ec='black')
plt.xlabel('Daily Users')
plt.show()

# %%
plt.plot(newDaily['time'], newDaily['metric_value'] ,linewidth=1 ,color='g')
