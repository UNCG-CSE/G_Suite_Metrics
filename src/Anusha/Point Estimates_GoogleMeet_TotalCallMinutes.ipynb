# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import random
import math

# %%
data_path2 = "C:/Users/Anusha/Documents/Copied on 9_26_19/Fall 2019/Data Science/Project/GoogleMeetUpdated2.csv"
data2 = pd.read_csv(data_path2)
data2['time'] = pd.to_datetime(data2['time'],utc=True)
data2.set_index('time', inplace=True)

# %%
pd.DataFrame(data2).hist(range=(0,8000), bins=543, ec='black', figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B363ADAB70>]],
#       dtype=object)
