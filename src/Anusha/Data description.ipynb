# %% [markdown]
# Raw data extraction to Pandas dataframes.

# %%
import pandas as pd
data_path = "20150323-20190817-google-metrics-export - 20150323-20190817-google-metrics-export.csv"
data = pd.read_csv(data_path)

# %% [markdown]
# Column names

# %%
data.head()
# Out:
#                            time  \
# 0  2015-03-23T00:00:00.000-0400
# 1  2015-03-23T00:00:00.000-0400
# 2  2015-03-23T00:00:00.000-0400
# 3  2015-03-23T00:00:00.000-0400
# 4  2015-03-23T00:00:00.000-0400
#
#                                          metric_name  metric_value
# 0  google.device_management:num_7day_android_4_1_...             0
# 1  google.device_management:num_7day_android_4_1_...             0
# 2  google.device_management:num_7day_android_4_2_...             0
# 3  google.device_management:num_7day_android_4_2_...             0
# 4  google.device_management:num_7day_android_4_3_...             0

# %% [markdown]
# Shape of data

# %%
data.shape
# Out:
# (611913, 3)

# %% [markdown]
# Total number of elements

# %%
data.size
# Out:
# 1835739

# %% [markdown]
# Number of dimensions

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# Maximum value in dataframe

# %%
data.loc[data['metric_value'].idxmax()]
# Out:
# time                2019-08-17T00:00:00.000-0400
# metric_name     google.accounts:used_quota_in_mb
# metric_value                           274032962
# Name: 611359, dtype: object

# %% [markdown]
# Minimun value in dataframe

# %%
data.loc[data['metric_value'].idxmin()]
# Out:
# time                                 2017-05-18T00:00:00.000-0400
# metric_name     google.drive:num_owned_items_with_visibility_p...
# metric_value                                              -376732
# Name: 213965, dtype: object

# %% [markdown]
# Finding total number of metric names

# %%
group_names = data.metric_name.unique()
len(group_names)
# Out:
# 649

# %% [markdown]
# Displaying Metric names in dataset

# %%
group_names
# Out:
# array(['google.device_management:num_7day_android_4_1_managed_devices',
#        'google.device_management:num_7day_android_4_1_managed_users',
#        'google.device_management:num_7day_android_4_2_managed_devices',
#        'google.device_management:num_7day_android_4_2_managed_users',
#        'google.device_management:num_7day_android_4_3_managed_devices',
#        'google.device_management:num_7day_android_4_3_managed_users',
#        'google.device_management:num_7day_android_4_4_managed_devices',
#        'google.device_management:num_7day_android_4_4_managed_users',
#        'google.device_management:num_7day_android_5_0_managed_devices',
#        'google.device_management:num_7day_android_5_0_managed_users',
#        'google.device_management:num_7day_android_managed_devices',
#        'google.device_management:num_7day_android_managed_users',
#        'google.device_management:num_7day_google_sync_managed_devices',
#        'google.device_management:num_7day_google_sync_managed_users',
#        'google.device_management:num_7day_ios_2_managed_devices',
#        'google.device_management:num_7day_ios_2_managed_users',
#        'google.device_management:num_7day_ios_3_managed_devices',
#        'google.device_management:num_7day_ios_3_managed_users',
#        'google.device_management:num_7day_ios_4_managed_devices',
#        'google.device_management:num_7day_ios_4_managed_users',
#        'google.device_management:num_7day_ios_5_managed_devices',
#        'google.device_management:num_7day_ios_5_managed_users',
#        'google.device_management:num_7day_ios_6_managed_devices',
#        'google.device_management:num_7day_ios_6_managed_users',
#        'google.device_management:num_7day_ios_7_managed_devices',
#        'google.device_management:num_7day_ios_7_managed_users',
#        'google.device_management:num_7day_ios_8_managed_devices',
#        'google.device_management:num_7day_ios_8_managed_users',
#        'google.device_management:num_7day_ios_managed_devices',
#        'google.device_management:num_7day_ios_managed_users',
#        'google.device_management:num_7day_total_managed_devices',
#        'google.device_management:num_7day_total_managed_users',
#        'google.gmail:num_1day_active_users',
#        'google.gmail:num_1day_imap_users',
#        'google.gmail:num_1day_pop_users',
#        'google.gmail:num_1day_webmail_users',
#        'google.gmail:num_30day_active_users',
#        'google.gmail:num_30day_imap_users',
#        'google.gmail:num_30day_pop_users',
#        'google.gmail:num_30day_webmail_users',
#        'google.gmail:num_7day_active_users',
#        'google.gmail:num_7day_imap_users',
#        'google.gmail:num_7day_pop_users',
#        'google.gmail:num_7day_webmail_users',
#        'google.gmail:num_emails_exchanged',
#        'google.gmail:num_emails_received', 'google.gmail:num_emails_sent',
#        'google.gmail:num_inbound_delivered_emails',
#        'google.gmail:num_inbound_encrypted_emails',
#        'google.gmail:num_inbound_non_spam_emails',
#        'google.gmail:num_inbound_rejected_emails',
#        'google.gmail:num_inbound_rerouted_emails',
#        'google.gmail:num_inbound_spam_emails',
#        'google.gmail:num_inbound_unencrypted_emails',
#        'google.gmail:num_outbound_delivered_emails',
#        'google.gmail:num_outbound_encrypted_emails',
#        'google.gmail:num_outbound_rejected_emails',
#        'google.gmail:num_outbound_rerouted_emails',
#        'google.gmail:num_outbound_unencrypted_emails',
#        'google.accounts:apps_total_licenses',
#        'google.accounts:apps_used_licenses',
#        'google.accounts:authorized_apps',
#        'google.accounts:coordinate_total_licenses',
#        'google.accounts:drive_used_quota_in_mb',
#        'google.accounts:gmail_used_quota_in_mb',
#        'google.accounts:gplus_photos_used_quota_in_mb',
#        'google.accounts:num_1day_logins',
#        'google.accounts:num_30day_logins',
#        'google.accounts:num_7day_logins',
#        'google.accounts:num_authorized_apps',
#        'google.accounts:num_delegated_admins',
#        'google.accounts:num_disabled_accounts',
#        'google.accounts:num_locked_users',
#        'google.accounts:num_super_admins',
#        'google.accounts:num_suspended_users', 'google.accounts:num_users',
#        'google.accounts:num_users_2sv_enforced',
#        'google.accounts:num_users_2sv_enrolled',
#        'google.accounts:num_users_2sv_enrolled_and_enforced',
#        'google.accounts:num_users_2sv_not_enforced',
#        'google.accounts:num_users_2sv_not_enrolled',
#        'google.accounts:num_users_2sv_not_enrolled_and_not_enforced',
#        'google.accounts:num_users_2sv_not_enrolled_but_enforced',
#        'google.accounts:num_users_used_quota_lt_50percent',
#        'google.accounts:total_quota_in_mb',
#        'google.accounts:used_quota_in_mb',
#        'google.accounts:vault_total_licenses',
#        'google.calendar:num_1day_active_users',
#        'google.calendar:num_30day_active_users',
#        'google.calendar:num_7day_active_users',
#        'google.device_management:num_1day_android_2_1_managed_devices',
#        'google.device_management:num_1day_android_2_1_managed_users',
#        'google.device_management:num_1day_android_2_2_managed_devices',
#        'google.device_management:num_1day_android_2_2_managed_users',
#        'google.device_management:num_1day_android_2_3_managed_devices',
#        'google.device_management:num_1day_android_2_3_managed_users',
#        'google.device_management:num_1day_android_2_4_managed_devices',
#        'google.device_management:num_1day_android_2_4_managed_users',
#        'google.device_management:num_1day_android_3_0_managed_devices',
#        'google.device_management:num_1day_android_3_0_managed_users',
#        'google.device_management:num_1day_android_3_1_managed_devices',
#        'google.device_management:num_1day_android_3_1_managed_users',
#        'google.device_management:num_1day_android_3_2_managed_devices',
#        'google.device_management:num_1day_android_3_2_managed_users',
#        'google.device_management:num_1day_android_4_0_managed_devices',
#        'google.device_management:num_1day_android_4_0_managed_users',
#        'google.device_management:num_1day_android_4_1_managed_devices',
#        'google.device_management:num_1day_android_4_1_managed_users',
#        'google.device_management:num_1day_android_4_2_managed_devices',
#        'google.device_management:num_1day_android_4_2_managed_users',
#        'google.device_management:num_1day_android_4_3_managed_devices',
#        'google.device_management:num_1day_android_4_3_managed_users',
#        'google.device_management:num_1day_android_4_4_managed_devices',
#        'google.device_management:num_1day_android_4_4_managed_users',
#        'google.device_management:num_1day_android_5_0_managed_devices',
#        'google.device_management:num_1day_android_5_0_managed_users',
#        'google.device_management:num_1day_android_managed_devices',
#        'google.device_management:num_1day_android_managed_users',
#        'google.device_management:num_1day_google_sync_managed_devices',
#        'google.device_management:num_1day_google_sync_managed_users',
#        'google.device_management:num_1day_ios_2_managed_devices',
#        'google.device_management:num_1day_ios_2_managed_users',
#        'google.device_management:num_1day_ios_3_managed_devices',
#        'google.device_management:num_1day_ios_3_managed_users',
#        'google.device_management:num_1day_ios_4_managed_devices',
#        'google.device_management:num_1day_ios_4_managed_users',
#        'google.device_management:num_1day_ios_5_managed_devices',
#        'google.device_management:num_1day_ios_5_managed_users',
#        'google.device_management:num_1day_ios_6_managed_devices',
#        'google.device_management:num_1day_ios_6_managed_users',
#        'google.device_management:num_1day_ios_7_managed_devices',
#        'google.device_management:num_1day_ios_7_managed_users',
#        'google.device_management:num_1day_ios_8_managed_devices',
#        'google.device_management:num_1day_ios_8_managed_users',
#        'google.device_management:num_1day_ios_managed_devices',
#        'google.device_management:num_1day_ios_managed_users',
#        'google.device_management:num_1day_total_managed_devices',
#        'google.device_management:num_1day_total_managed_users',
#        'google.device_management:num_30day_android_2_1_managed_devices',
#        'google.device_management:num_30day_android_2_1_managed_users',
#        'google.device_management:num_30day_android_2_2_managed_devices',
#        'google.device_management:num_30day_android_2_2_managed_users',
#        'google.device_management:num_30day_android_2_3_managed_devices',
#        'google.device_management:num_30day_android_2_3_managed_users',
#        'google.device_management:num_30day_android_2_4_managed_devices',
#        'google.device_management:num_30day_android_2_4_managed_users',
#        'google.device_management:num_30day_android_3_0_managed_devices',
#        'google.device_management:num_30day_android_3_0_managed_users',
#        'google.device_management:num_30day_android_3_1_managed_devices',
#        'google.device_management:num_30day_android_3_1_managed_users',
#        'google.device_management:num_30day_android_3_2_managed_devices',
#        'google.device_management:num_30day_android_3_2_managed_users',
#        'google.device_management:num_30day_android_4_0_managed_devices',
#        'google.device_management:num_30day_android_4_0_managed_users',
#        'google.device_management:num_30day_android_4_1_managed_devices',
#        'google.device_management:num_30day_android_4_1_managed_users',
#        'google.device_management:num_30day_android_4_2_managed_devices',
#        'google.device_management:num_30day_android_4_2_managed_users',
#        'google.device_management:num_30day_android_4_3_managed_devices',
#        'google.device_management:num_30day_android_4_3_managed_users',
#        'google.device_management:num_30day_android_4_4_managed_devices',
#        'google.device_management:num_30day_android_4_4_managed_users',
#        'google.device_management:num_30day_android_5_0_managed_devices',
#        'google.device_management:num_30day_android_5_0_managed_users',
#        'google.device_management:num_30day_android_managed_devices',
#        'google.device_management:num_30day_android_managed_users',
#        'google.device_management:num_30day_google_sync_managed_devices',
#        'google.device_management:num_30day_google_sync_managed_users',
#        'google.device_management:num_30day_ios_2_managed_devices',
#        'google.device_management:num_30day_ios_2_managed_users',
#        'google.device_management:num_30day_ios_3_managed_devices',
#        'google.device_management:num_30day_ios_3_managed_users',
#        'google.device_management:num_30day_ios_4_managed_devices',
#        'google.device_management:num_30day_ios_4_managed_users',
#        'google.device_management:num_30day_ios_5_managed_devices',
#        'google.device_management:num_30day_ios_5_managed_users',
#        'google.device_management:num_30day_ios_6_managed_devices',
#        'google.device_management:num_30day_ios_6_managed_users',
#        'google.device_management:num_30day_ios_7_managed_devices',
#        'google.device_management:num_30day_ios_7_managed_users',
#        'google.device_management:num_30day_ios_8_managed_devices',
#        'google.device_management:num_30day_ios_8_managed_users',
#        'google.device_management:num_30day_ios_managed_devices',
#        'google.device_management:num_30day_ios_managed_users',
#        'google.device_management:num_30day_total_managed_devices',
#        'google.device_management:num_30day_total_managed_users',
#        'google.device_management:num_7day_android_2_1_managed_devices',
#        'google.device_management:num_7day_android_2_1_managed_users',
#        'google.device_management:num_7day_android_2_2_managed_devices',
#        'google.device_management:num_7day_android_2_2_managed_users',
#        'google.device_management:num_7day_android_2_3_managed_devices',
#        'google.device_management:num_7day_android_2_3_managed_users',
#        'google.device_management:num_7day_android_2_4_managed_devices',
#        'google.device_management:num_7day_android_2_4_managed_users',
#        'google.device_management:num_7day_android_3_0_managed_devices',
#        'google.device_management:num_7day_android_3_0_managed_users',
#        'google.device_management:num_7day_android_3_1_managed_devices',
#        'google.device_management:num_7day_android_3_1_managed_users',
#        'google.device_management:num_7day_android_3_2_managed_devices',
#        'google.device_management:num_7day_android_3_2_managed_users',
#        'google.device_management:num_7day_android_4_0_managed_devices',
#        'google.device_management:num_7day_android_4_0_managed_users',
#        'google.docs:num_1day_active_users',
#        'google.docs:num_30day_active_users',
#        'google.docs:num_7day_active_users', 'google.docs:num_docs',
#        'google.docs:num_docs_edited',
#        'google.docs:num_docs_externally_visible',
#        'google.docs:num_docs_internally_visible',
#        'google.docs:num_docs_not_edited_for_12months',
#        'google.docs:num_docs_not_edited_for_3months',
#        'google.docs:num_docs_not_edited_for_6months',
#        'google.docs:num_docs_not_viewed_for_12months',
#        'google.docs:num_docs_not_viewed_for_3months',
#        'google.docs:num_docs_not_viewed_for_6months',
#        'google.docs:num_docs_shared_outside_domain',
#        'google.docs:num_docs_viewed',
#        'google.docs:num_docs_with_visibility_anyone_with_link',
#        'google.docs:num_docs_with_visibility_people_at_domain',
#        'google.docs:num_docs_with_visibility_people_at_domain_with_link',
#        'google.docs:num_docs_with_visibility_private',
#        'google.docs:num_docs_with_visibility_public',
#        'google.docs:num_drawings', 'google.docs:num_drawings_edited',
#        'google.docs:num_drawings_viewed', 'google.docs:num_forms',
#        'google.docs:num_forms_edited', 'google.docs:num_forms_viewed',
#        'google.docs:num_presentations',
#        'google.docs:num_presentations_edited',
#        'google.docs:num_presentations_viewed',
#        'google.docs:num_shared_docs', 'google.docs:num_spreadsheets',
#        'google.docs:num_spreadsheets_edited',
#        'google.docs:num_spreadsheets_viewed',
#        'google.docs:num_text_documents',
#        'google.docs:num_text_documents_edited',
#        'google.docs:num_text_documents_viewed',
#        'google.docs:num_uploaded_files',
#        'google.docs:num_uploaded_files_edited',
#        'google.docs:num_uploaded_files_viewed',
#        'google.gplus:num_1day_active_users',
#        'google.gplus:num_30day_active_users',
#        'google.gplus:num_7day_active_users',
#        'google.gplus:num_video_calls',
#        'google.gplus:num_video_conferences',
#        'google.gplus:total_video_call_minutes', 'google.sites:num_sites',
#        'google.sites:num_sites_created',
#        'google.accounts:num_security_keys',
#        'google.device_management:num_1day_android_5_1_managed_devices',
#        'google.device_management:num_1day_android_5_1_managed_users',
#        'google.device_management:num_30day_android_5_1_managed_devices',
#        'google.device_management:num_30day_android_5_1_managed_users',
#        'google.device_management:num_7day_android_5_1_managed_devices',
#        'google.device_management:num_7day_android_5_1_managed_users',
#        'google.accounts:num_users_less_secure_apps_access_allowed',
#        'google.accounts:num_users_less_secure_apps_access_denied',
#        'google.accounts:num_users_overridden_names',
#        'google.device_management:num_1day_android_6_0_managed_devices',
#        'google.device_management:num_1day_android_6_0_managed_users',
#        'google.device_management:num_1day_ios_9_managed_devices',
#        'google.device_management:num_1day_ios_9_managed_users',
#        'google.device_management:num_30day_android_6_0_managed_devices',
#        'google.device_management:num_30day_android_6_0_managed_users',
#        'google.device_management:num_30day_ios_9_managed_devices',
#        'google.device_management:num_30day_ios_9_managed_users',
#        'google.device_management:num_7day_android_6_0_managed_devices',
#        'google.device_management:num_7day_android_6_0_managed_users',
#        'google.device_management:num_7day_ios_9_managed_devices',
#        'google.device_management:num_7day_ios_9_managed_users',
#        'google.device_management:num_total_unmanaged_users',
#        'google.device_management:num_total_users',
#        'google.accounts:num_chrome_30day_active_users',
#        'google.accounts:num_chrome_7day_active_users',
#        'google.accounts:num_desktop_30day_active_users',
#        'google.accounts:num_desktop_7day_active_users',
#        'google.accounts:num_firefox_30day_active_users',
#        'google.accounts:num_firefox_7day_active_users',
#        'google.accounts:num_ie_30day_active_users',
#        'google.accounts:num_ie_7day_active_users',
#        'google.accounts:num_mobile_30day_active_users',
#        'google.accounts:num_mobile_7day_active_users',
#        'google.accounts:num_opera_30day_active_users',
#        'google.accounts:num_opera_7day_active_users',
#        'google.accounts:num_other_browsers_30day_active_users',
#        'google.accounts:num_other_browsers_7day_active_users',
#        'google.accounts:num_safari_30day_active_users',
#        'google.accounts:num_safari_7day_active_users',
#        'google.gplus:num_video_calls_android',
#        'google.gplus:num_video_calls_cfm',
#        'google.gplus:num_video_calls_ios',
#        'google.gplus:num_video_calls_web',
#        'google.gplus:num_video_conferences_android',
#        'google.gplus:num_video_conferences_cfm',
#        'google.gplus:num_video_conferences_ios',
#        'google.gplus:num_video_conferences_mobile',
#        'google.gplus:num_video_conferences_web',
#        'google.gplus:total_video_call_minutes_android',
#        'google.gplus:total_video_call_minutes_cfm',
#        'google.gplus:total_video_call_minutes_ios',
#        'google.gplus:total_video_call_minutes_web',
#        'google.docs:num_active_users',
#        'google.docs:num_owned_google_documents_created',
#        'google.docs:num_owned_google_documents_edited',
#        'google.docs:num_owned_google_documents_trashed',
#        'google.docs:num_owned_google_documents_viewed',
#        'google.docs:num_owned_google_drawings_created',
#        'google.docs:num_owned_google_drawings_edited',
#        'google.docs:num_owned_google_drawings_trashed',
#        'google.docs:num_owned_google_drawings_viewed',
#        'google.docs:num_owned_google_forms_created',
#        'google.docs:num_owned_google_forms_edited',
#        'google.docs:num_owned_google_forms_trashed',
#        'google.docs:num_owned_google_forms_viewed',
#        'google.docs:num_owned_google_presentations_created',
#        'google.docs:num_owned_google_presentations_edited',
#        'google.docs:num_owned_google_presentations_trashed',
#        'google.docs:num_owned_google_presentations_viewed',
#        'google.docs:num_owned_google_spreadsheets_created',
#        'google.docs:num_owned_google_spreadsheets_edited',
#        'google.docs:num_owned_google_spreadsheets_trashed',
#        'google.docs:num_owned_google_spreadsheets_viewed',
#        'google.docs:num_owned_items_created',
#        'google.docs:num_owned_items_edited',
#        'google.docs:num_owned_items_trashed',
#        'google.docs:num_owned_items_viewed',
#        'google.docs:num_owned_other_types_created',
#        'google.docs:num_owned_other_types_edited',
#        'google.docs:num_owned_other_types_trashed',
#        'google.docs:num_owned_other_types_viewed',
#        'google.device_management:num_1day_android_7_0_managed_devices',
#        'google.device_management:num_1day_android_7_0_managed_users',
#        'google.device_management:num_1day_ios_10_managed_devices',
#        'google.device_management:num_1day_ios_10_managed_users',
#        'google.device_management:num_30day_android_7_0_managed_devices',
#        'google.device_management:num_30day_android_7_0_managed_users',
#        'google.device_management:num_30day_ios_10_managed_devices',
#        'google.device_management:num_30day_ios_10_managed_users',
#        'google.device_management:num_7day_android_7_0_managed_devices',
#        'google.device_management:num_7day_android_7_0_managed_users',
#        'google.device_management:num_7day_ios_10_managed_devices',
#        'google.device_management:num_7day_ios_10_managed_users',
#        'google.gplus:num_new_users', 'google.gplus:num_plusones',
#        'google.gplus:num_replies', 'google.gplus:num_reshares',
#        'google.gplus:num_shares', 'google.gplus:num_stream_items_read',
#        'google._empty_', 'google.drive:num_1day_active_users',
#        'google.drive:num_collaborators', 'google.drive:num_consumers',
#        'google.drive:num_creators',
#        'google.drive:num_google_documents_created',
#        'google.drive:num_google_documents_edited',
#        'google.drive:num_google_documents_trashed',
#        'google.drive:num_google_documents_viewed',
#        'google.drive:num_google_drawings_created',
#        'google.drive:num_google_drawings_edited',
#        'google.drive:num_google_drawings_trashed',
#        'google.drive:num_google_drawings_viewed',
#        'google.drive:num_google_forms_created',
#        'google.drive:num_google_forms_edited',
#        'google.drive:num_google_forms_trashed',
#        'google.drive:num_google_forms_viewed',
#        'google.drive:num_google_presentations_created',
#        'google.drive:num_google_presentations_edited',
#        'google.drive:num_google_presentations_trashed',
#        'google.drive:num_google_presentations_viewed',
#        'google.drive:num_google_spreadsheets_created',
#        'google.drive:num_google_spreadsheets_edited',
#        'google.drive:num_google_spreadsheets_trashed',
#        'google.drive:num_google_spreadsheets_viewed',
#        'google.drive:num_items_created', 'google.drive:num_items_edited',
#        'google.drive:num_items_trashed', 'google.drive:num_items_viewed',
#        'google.drive:num_other_types_created',
#        'google.drive:num_other_types_edited',
#        'google.drive:num_other_types_trashed',
#        'google.drive:num_other_types_viewed',
#        'google.drive:num_owned_google_documents_added',
#        'google.drive:num_owned_google_documents_created',
#        'google.drive:num_owned_google_documents_delta',
#        'google.drive:num_owned_google_documents_edited',
#        'google.drive:num_owned_google_documents_removed',
#        'google.drive:num_owned_google_documents_trashed',
#        'google.drive:num_owned_google_documents_viewed',
#        'google.drive:num_owned_google_drawings_added',
#        'google.drive:num_owned_google_drawings_created',
#        'google.drive:num_owned_google_drawings_delta',
#        'google.drive:num_owned_google_drawings_edited',
#        'google.drive:num_owned_google_drawings_removed',
#        'google.drive:num_owned_google_drawings_trashed',
#        'google.drive:num_owned_google_drawings_viewed',
#        'google.drive:num_owned_google_forms_added',
#        'google.drive:num_owned_google_forms_created',
#        'google.drive:num_owned_google_forms_delta',
#        'google.drive:num_owned_google_forms_edited',
#        'google.drive:num_owned_google_forms_removed',
#        'google.drive:num_owned_google_forms_trashed',
#        'google.drive:num_owned_google_forms_viewed',
#        'google.drive:num_owned_google_presentations_added',
#        'google.drive:num_owned_google_presentations_created',
#        'google.drive:num_owned_google_presentations_delta',
#        'google.drive:num_owned_google_presentations_edited',
#        'google.drive:num_owned_google_presentations_removed',
#        'google.drive:num_owned_google_presentations_trashed',
#        'google.drive:num_owned_google_presentations_viewed',
#        'google.drive:num_owned_google_spreadsheets_added',
#        'google.drive:num_owned_google_spreadsheets_created',
#        'google.drive:num_owned_google_spreadsheets_delta',
#        'google.drive:num_owned_google_spreadsheets_edited',
#        'google.drive:num_owned_google_spreadsheets_removed',
#        'google.drive:num_owned_google_spreadsheets_trashed',
#        'google.drive:num_owned_google_spreadsheets_viewed',
#        'google.drive:num_owned_items_added',
#        'google.drive:num_owned_items_created',
#        'google.drive:num_owned_items_delta',
#        'google.drive:num_owned_items_edited',
#        'google.drive:num_owned_items_removed',
#        'google.drive:num_owned_items_trashed',
#        'google.drive:num_owned_items_viewed',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_added',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_delta',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_removed',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_with_link_added',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_with_link_delta',
#        'google.drive:num_owned_items_with_visibility_anyone_in_domain_with_link_removed',
#        'google.drive:num_owned_items_with_visibility_anyone_with_link_added',
#        'google.drive:num_owned_items_with_visibility_anyone_with_link_delta',
#        'google.drive:num_owned_items_with_visibility_anyone_with_link_removed',
#        'google.drive:num_owned_items_with_visibility_private_added',
#        'google.drive:num_owned_items_with_visibility_private_delta',
#        'google.drive:num_owned_items_with_visibility_private_removed',
#        'google.drive:num_owned_items_with_visibility_public_added',
#        'google.drive:num_owned_items_with_visibility_public_delta',
#        'google.drive:num_owned_items_with_visibility_public_removed',
#        'google.drive:num_owned_items_with_visibility_shared_externally_added',
#        'google.drive:num_owned_items_with_visibility_shared_externally_delta',
#        'google.drive:num_owned_items_with_visibility_shared_externally_removed',
#        'google.drive:num_owned_items_with_visibility_shared_internally_added',
#        'google.drive:num_owned_items_with_visibility_shared_internally_delta',
#        'google.drive:num_owned_items_with_visibility_shared_internally_removed',
#        'google.drive:num_owned_items_with_visibility_unknown_added',
#        'google.drive:num_owned_items_with_visibility_unknown_delta',
#        'google.drive:num_owned_items_with_visibility_unknown_removed',
#        'google.drive:num_owned_other_types_added',
#        'google.drive:num_owned_other_types_created',
#        'google.drive:num_owned_other_types_delta',
#        'google.drive:num_owned_other_types_edited',
#        'google.drive:num_owned_other_types_removed',
#        'google.drive:num_owned_other_types_trashed',
#        'google.drive:num_owned_other_types_viewed',
#        'google.drive:num_sharers', 'google.cros:num_30day_active_devices',
#        'google.cros:num_7day_active_devices',
#        'google.cros:num_beta_channel_devices',
#        'google.cros:num_dev_boot_devices',
#        'google.cros:num_dev_channel_devices',
#        'google.cros:num_other_channel_devices',
#        'google.cros:num_stable_channel_devices',
#        'google.cros:num_unreported_boot_devices',
#        'google.cros:num_unreported_channel_devices',
#        'google.cros:num_verified_boot_devices',
#        'google.device_management:num_1day_android_7_1_managed_devices',
#        'google.device_management:num_1day_android_7_1_managed_users',
#        'google.device_management:num_30day_android_7_1_managed_devices',
#        'google.device_management:num_30day_android_7_1_managed_users',
#        'google.device_management:num_7day_android_7_1_managed_devices',
#        'google.device_management:num_7day_android_7_1_managed_users',
#        'google.gplus:num_7day_active_cfm_devices',
#        'google.classroom:num_14day_active_courses',
#        'google.classroom:num_1day_students',
#        'google.classroom:num_1day_teachers',
#        'google.classroom:num_1day_users',
#        'google.classroom:num_30day_students',
#        'google.classroom:num_30day_teachers',
#        'google.classroom:num_30day_users',
#        'google.classroom:num_7day_students',
#        'google.classroom:num_7day_teachers',
#        'google.classroom:num_7day_users',
#        'google.classroom:num_courses_created',
#        'google.classroom:num_student_posts_created',
#        'google.classroom:num_teacher_posts_created',
#        'google.drive:num_1day_google_documents_active_users',
#        'google.drive:num_1day_google_drawings_active_users',
#        'google.drive:num_1day_google_forms_active_users',
#        'google.drive:num_1day_google_presentations_active_users',
#        'google.drive:num_1day_google_spreadsheets_active_users',
#        'google.drive:num_1day_other_types_active_users',
#        'google.drive:num_30day_active_users',
#        'google.drive:num_30day_google_documents_active_users',
#        'google.drive:num_30day_google_drawings_active_users',
#        'google.drive:num_30day_google_forms_active_users',
#        'google.drive:num_30day_google_presentations_active_users',
#        'google.drive:num_30day_google_spreadsheets_active_users',
#        'google.drive:num_30day_other_types_active_users',
#        'google.drive:num_7day_active_users',
#        'google.drive:num_7day_google_documents_active_users',
#        'google.drive:num_7day_google_drawings_active_users',
#        'google.drive:num_7day_google_forms_active_users',
#        'google.drive:num_7day_google_presentations_active_users',
#        'google.drive:num_7day_google_spreadsheets_active_users',
#        'google.drive:num_7day_other_types_active_users',
#        'google.gplus:num_collections',
#        'google.gplus:num_collections_organization_private',
#        'google.gplus:num_collections_organization_wide',
#        'google.gplus:num_collections_public',
#        'google.gplus:num_communities',
#        'google.gplus:num_communities_organization_private',
#        'google.gplus:num_communities_organization_wide',
#        'google.gplus:num_communities_private',
#        'google.gplus:num_communities_public',
#        'google.app_maker:num_1day_active_apps',
#        'google.app_maker:num_1day_active_users',
#        'google.apps_scripts:num_1day_active_apps',
#        'google.apps_scripts:num_1day_active_users',
#        'google.drive:num_owned_external_items_added',
#        'google.drive:num_owned_internal_items_added',
#        'google.device_management:num_1day_android_8_0_managed_devices',
#        'google.device_management:num_1day_android_8_0_managed_users',
#        'google.device_management:num_1day_ios_11_managed_devices',
#        'google.device_management:num_1day_ios_11_managed_users',
#        'google.device_management:num_30day_android_8_0_managed_devices',
#        'google.device_management:num_30day_android_8_0_managed_users',
#        'google.device_management:num_30day_ios_11_managed_devices',
#        'google.device_management:num_30day_ios_11_managed_users',
#        'google.device_management:num_7day_android_8_0_managed_devices',
#        'google.device_management:num_7day_android_8_0_managed_users',
#        'google.device_management:num_7day_ios_11_managed_devices',
#        'google.device_management:num_7day_ios_11_managed_users',
#        'google.meet:average_meeting_minutes',
#        'google.meet:average_meeting_minutes_with_11_to_15_calls',
#        'google.meet:average_meeting_minutes_with_16_to_25_calls',
#        'google.meet:average_meeting_minutes_with_26_to_50_calls',
#        'google.meet:average_meeting_minutes_with_2_calls',
#        'google.meet:average_meeting_minutes_with_3_to_5_calls',
#        'google.meet:average_meeting_minutes_with_6_to_10_calls',
#        'google.meet:lonely_meetings',
#        'google.meet:max_concurrent_usage_chromebase',
#        'google.meet:max_concurrent_usage_chromebox',
#        'google.meet:num_1day_active_users',
#        'google.meet:num_30day_active_users',
#        'google.meet:num_7day_active_users', 'google.meet:num_calls',
#        'google.meet:num_calls_android',
#        'google.meet:num_calls_by_external_users',
#        'google.meet:num_calls_by_internal_users',
#        'google.meet:num_calls_by_pstn_in_users',
#        'google.meet:num_calls_chromebase',
#        'google.meet:num_calls_chromebox', 'google.meet:num_calls_ios',
#        'google.meet:num_calls_jamboard',
#        'google.meet:num_calls_unknown_client',
#        'google.meet:num_calls_web', 'google.meet:num_meetings',
#        'google.meet:num_meetings_android',
#        'google.meet:num_meetings_chromebase',
#        'google.meet:num_meetings_chromebox',
#        'google.meet:num_meetings_ios',
#        'google.meet:num_meetings_jamboard',
#        'google.meet:num_meetings_unknown_client',
#        'google.meet:num_meetings_web',
#        'google.meet:num_meetings_with_11_to_15_calls',
#        'google.meet:num_meetings_with_16_to_25_calls',
#        'google.meet:num_meetings_with_26_to_50_calls',
#        'google.meet:num_meetings_with_2_calls',
#        'google.meet:num_meetings_with_3_to_5_calls',
#        'google.meet:num_meetings_with_6_to_10_calls',
#        'google.meet:num_meetings_with_external_users',
#        'google.meet:num_meetings_with_pstn_in_users',
#        'google.meet:total_call_minutes',
#        'google.meet:total_call_minutes_android',
#        'google.meet:total_call_minutes_by_external_users',
#        'google.meet:total_call_minutes_by_internal_users',
#        'google.meet:total_call_minutes_by_pstn_in_users',
#        'google.meet:total_call_minutes_chromebase',
#        'google.meet:total_call_minutes_chromebox',
#        'google.meet:total_call_minutes_ios',
#        'google.meet:total_call_minutes_jamboard',
#        'google.meet:total_call_minutes_unknown_client',
#        'google.meet:total_call_minutes_web',
#        'google.meet:total_meeting_minutes',
#        'google.drive:num_1day_google_sites_active_users',
#        'google.drive:num_30day_google_sites_active_users',
#        'google.drive:num_7day_google_sites_active_users',
#        'google.drive:num_google_sites_created',
#        'google.drive:num_google_sites_edited',
#        'google.drive:num_google_sites_trashed',
#        'google.drive:num_google_sites_viewed',
#        'google.drive:num_owned_google_sites_added',
#        'google.drive:num_owned_google_sites_created',
#        'google.drive:num_owned_google_sites_delta',
#        'google.drive:num_owned_google_sites_edited',
#        'google.drive:num_owned_google_sites_removed',
#        'google.drive:num_owned_google_sites_trashed',
#        'google.drive:num_owned_google_sites_viewed',
#        'google.meet:num_calls_by_pstn_out_users',
#        'google.meet:num_meetings_with_pstn_out_users',
#        'google.meet:total_call_minutes_by_pstn_out_users',
#        'google.accounts:num_archived_users',
#        'google.accounts:team_drive_used_quota_in_mb',
#        'google.device_management:num_1day_android_8_1_managed_devices',
#        'google.device_management:num_1day_android_8_1_managed_users',
#        'google.device_management:num_1day_android_9_0_managed_devices',
#        'google.device_management:num_1day_android_9_0_managed_users',
#        'google.device_management:num_1day_ios_12_managed_devices',
#        'google.device_management:num_1day_ios_12_managed_users',
#        'google.device_management:num_30day_android_8_1_managed_devices',
#        'google.device_management:num_30day_android_8_1_managed_users',
#        'google.device_management:num_30day_android_9_0_managed_devices',
#        'google.device_management:num_30day_android_9_0_managed_users',
#        'google.device_management:num_30day_ios_12_managed_devices',
#        'google.device_management:num_30day_ios_12_managed_users',
#        'google.device_management:num_7day_android_8_1_managed_devices',
#        'google.device_management:num_7day_android_8_1_managed_users',
#        'google.device_management:num_7day_android_9_0_managed_devices',
#        'google.device_management:num_7day_android_9_0_managed_users',
#        'google.device_management:num_7day_ios_12_managed_devices',
#        'google.device_management:num_7day_ios_12_managed_users',
#        'google.drive:num_monthly_active_users',
#        'google.device_management:num_1day_desktop_chrome_managed_devices',
#        'google.device_management:num_1day_desktop_chrome_managed_users',
#        'google.device_management:num_1day_desktop_linux_managed_devices',
#        'google.device_management:num_1day_desktop_linux_managed_users',
#        'google.device_management:num_1day_desktop_mac_managed_devices',
#        'google.device_management:num_1day_desktop_mac_managed_users',
#        'google.device_management:num_1day_desktop_windows_managed_devices',
#        'google.device_management:num_1day_desktop_windows_managed_users',
#        'google.device_management:num_30day_desktop_chrome_managed_devices',
#        'google.device_management:num_30day_desktop_chrome_managed_users',
#        'google.device_management:num_30day_desktop_linux_managed_devices',
#        'google.device_management:num_30day_desktop_linux_managed_users',
#        'google.device_management:num_30day_desktop_mac_managed_devices',
#        'google.device_management:num_30day_desktop_mac_managed_users',
#        'google.device_management:num_30day_desktop_windows_managed_devices',
#        'google.device_management:num_30day_desktop_windows_managed_users',
#        'google.device_management:num_7day_desktop_chrome_managed_devices',
#        'google.device_management:num_7day_desktop_chrome_managed_users',
#        'google.device_management:num_7day_desktop_linux_managed_devices',
#        'google.device_management:num_7day_desktop_linux_managed_users',
#        'google.device_management:num_7day_desktop_mac_managed_devices',
#        'google.device_management:num_7day_desktop_mac_managed_users',
#        'google.device_management:num_7day_desktop_windows_managed_devices',
#        'google.device_management:num_7day_desktop_windows_managed_users',
#        'google.cros:device_version_distribution',
#        'google.accounts:shared_drive_used_quota_in_mb'], dtype=object)

# %% [markdown]
# Splitting data based on the year

# %%
year2015 = data[data['time'].str.startswith('2015')]
year2015
# Out:
#                                time  \
# 0      2015-03-23T00:00:00.000-0400
# 1      2015-03-23T00:00:00.000-0400
# 2      2015-03-23T00:00:00.000-0400
# 3      2015-03-23T00:00:00.000-0400
# 4      2015-03-23T00:00:00.000-0400
# 5      2015-03-23T00:00:00.000-0400
# 6      2015-03-23T00:00:00.000-0400
# 7      2015-03-23T00:00:00.000-0400
# 8      2015-03-23T00:00:00.000-0400
# 9      2015-03-23T00:00:00.000-0400
# 10     2015-03-23T00:00:00.000-0400
# 11     2015-03-23T00:00:00.000-0400
# 12     2015-03-23T00:00:00.000-0400
# 13     2015-03-23T00:00:00.000-0400
# 14     2015-03-23T00:00:00.000-0400
# 15     2015-03-23T00:00:00.000-0400
# 16     2015-03-23T00:00:00.000-0400
# 17     2015-03-23T00:00:00.000-0400
# 18     2015-03-23T00:00:00.000-0400
# 19     2015-03-23T00:00:00.000-0400
# 20     2015-03-23T00:00:00.000-0400
# 21     2015-03-23T00:00:00.000-0400
# 22     2015-03-23T00:00:00.000-0400
# 23     2015-03-23T00:00:00.000-0400
# 24     2015-03-23T00:00:00.000-0400
# 25     2015-03-23T00:00:00.000-0400
# 26     2015-03-23T00:00:00.000-0400
# 27     2015-03-23T00:00:00.000-0400
# 28     2015-03-23T00:00:00.000-0400
# 29     2015-03-23T00:00:00.000-0400
# ...                             ...
# 69699  2015-12-31T00:00:00.000-0500
# 69700  2015-12-31T00:00:00.000-0500
# 69701  2015-12-31T00:00:00.000-0500
# 69702  2015-12-31T00:00:00.000-0500
# 69703  2015-12-31T00:00:00.000-0500
# 69704  2015-12-31T00:00:00.000-0500
# 69705  2015-12-31T00:00:00.000-0500
# 69706  2015-12-31T00:00:00.000-0500
# 69707  2015-12-31T00:00:00.000-0500
# 69708  2015-12-31T00:00:00.000-0500
# 69709  2015-12-31T00:00:00.000-0500
# 69710  2015-12-31T00:00:00.000-0500
# 69711  2015-12-31T00:00:00.000-0500
# 69712  2015-12-31T00:00:00.000-0500
# 69713  2015-12-31T00:00:00.000-0500
# 69714  2015-12-31T00:00:00.000-0500
# 69715  2015-12-31T00:00:00.000-0500
# 69716  2015-12-31T00:00:00.000-0500
# 69717  2015-12-31T00:00:00.000-0500
# 69718  2015-12-31T00:00:00.000-0500
# 69719  2015-12-31T00:00:00.000-0500
# 69720  2015-12-31T00:00:00.000-0500
# 69721  2015-12-31T00:00:00.000-0500
# 69722  2015-12-31T00:00:00.000-0500
# 69723  2015-12-31T00:00:00.000-0500
# 69724  2015-12-31T00:00:00.000-0500
# 69725  2015-12-31T00:00:00.000-0500
# 69726  2015-12-31T00:00:00.000-0500
# 69727  2015-12-31T00:00:00.000-0500
# 69728  2015-12-31T00:00:00.000-0500
#
#                                              metric_name  metric_value
# 0      google.device_management:num_7day_android_4_1_...             0
# 1      google.device_management:num_7day_android_4_1_...             0
# 2      google.device_management:num_7day_android_4_2_...             0
# 3      google.device_management:num_7day_android_4_2_...             0
# 4      google.device_management:num_7day_android_4_3_...             0
# 5      google.device_management:num_7day_android_4_3_...             0
# 6      google.device_management:num_7day_android_4_4_...             0
# 7      google.device_management:num_7day_android_4_4_...             0
# 8      google.device_management:num_7day_android_5_0_...             0
# 9      google.device_management:num_7day_android_5_0_...             0
# 10     google.device_management:num_7day_android_mana...             0
# 11     google.device_management:num_7day_android_mana...             0
# 12     google.device_management:num_7day_google_sync_...             0
# 13     google.device_management:num_7day_google_sync_...             0
# 14     google.device_management:num_7day_ios_2_manage...             0
# 15     google.device_management:num_7day_ios_2_manage...             0
# 16     google.device_management:num_7day_ios_3_manage...             0
# 17     google.device_management:num_7day_ios_3_manage...             0
# 18     google.device_management:num_7day_ios_4_manage...             0
# 19     google.device_management:num_7day_ios_4_manage...             0
# 20     google.device_management:num_7day_ios_5_manage...             0
# 21     google.device_management:num_7day_ios_5_manage...             0
# 22     google.device_management:num_7day_ios_6_manage...             0
# 23     google.device_management:num_7day_ios_6_manage...             0
# 24     google.device_management:num_7day_ios_7_manage...             0
# 25     google.device_management:num_7day_ios_7_manage...             0
# 26     google.device_management:num_7day_ios_8_manage...             0
# 27     google.device_management:num_7day_ios_8_manage...             0
# 28     google.device_management:num_7day_ios_managed_...             0
# 29     google.device_management:num_7day_ios_managed_...             0
# ...                                                  ...           ...
# 69699                  google.gmail:num_30day_imap_users         12758
# 69700                   google.gmail:num_30day_pop_users           130
# 69701               google.gmail:num_30day_webmail_users         21403
# 69702                 google.gmail:num_7day_active_users         20769
# 69703                   google.gmail:num_7day_imap_users         11320
# 69704                    google.gmail:num_7day_pop_users           119
# 69705                google.gmail:num_7day_webmail_users          9910
# 69706                  google.gmail:num_emails_exchanged        172713
# 69707                   google.gmail:num_emails_received        168201
# 69708                       google.gmail:num_emails_sent          4512
# 69709          google.gmail:num_inbound_delivered_emails        153625
# 69710          google.gmail:num_inbound_encrypted_emails         62026
# 69711           google.gmail:num_inbound_non_spam_emails        108818
# 69712           google.gmail:num_inbound_rejected_emails             0
# 69713           google.gmail:num_inbound_rerouted_emails            11
# 69714               google.gmail:num_inbound_spam_emails         44837
# 69715        google.gmail:num_inbound_unencrypted_emails         91629
# 69716         google.gmail:num_outbound_delivered_emails          3929
# 69717         google.gmail:num_outbound_encrypted_emails          6240
# 69718          google.gmail:num_outbound_rejected_emails           118
# 69719          google.gmail:num_outbound_rerouted_emails             1
# 69720       google.gmail:num_outbound_unencrypted_emails          1576
# 69721                 google.gplus:num_1day_active_users           896
# 69722                google.gplus:num_30day_active_users          4946
# 69723                 google.gplus:num_7day_active_users          2279
# 69724                       google.gplus:num_video_calls            49
# 69725                 google.gplus:num_video_conferences            37
# 69726              google.gplus:total_video_call_minutes          1618
# 69727                             google.sites:num_sites          9753
# 69728                     google.sites:num_sites_created             0
#
# [69729 rows x 3 columns]

# %%
year2015.to_csv('FirstYear.csv')

# %%
year2016 = data[data['time'].str.startswith('2016')]
year2016
# Out:
#                                 time  \
# 69729   2016-01-01T00:00:00.000-0500
# 69730   2016-01-01T00:00:00.000-0500
# 69731   2016-01-01T00:00:00.000-0500
# 69732   2016-01-01T00:00:00.000-0500
# 69733   2016-01-01T00:00:00.000-0500
# 69734   2016-01-01T00:00:00.000-0500
# 69735   2016-01-01T00:00:00.000-0500
# 69736   2016-01-01T00:00:00.000-0500
# 69737   2016-01-01T00:00:00.000-0500
# 69738   2016-01-01T00:00:00.000-0500
# 69739   2016-01-01T00:00:00.000-0500
# 69740   2016-01-01T00:00:00.000-0500
# 69741   2016-01-01T00:00:00.000-0500
# 69742   2016-01-01T00:00:00.000-0500
# 69743   2016-01-01T00:00:00.000-0500
# 69744   2016-01-01T00:00:00.000-0500
# 69745   2016-01-01T00:00:00.000-0500
# 69746   2016-01-01T00:00:00.000-0500
# 69747   2016-01-01T00:00:00.000-0500
# 69748   2016-01-01T00:00:00.000-0500
# 69749   2016-01-01T00:00:00.000-0500
# 69750   2016-01-01T00:00:00.000-0500
# 69751   2016-01-01T00:00:00.000-0500
# 69752   2016-01-01T00:00:00.000-0500
# 69753   2016-01-01T00:00:00.000-0500
# 69754   2016-01-01T00:00:00.000-0500
# 69755   2016-01-01T00:00:00.000-0500
# 69756   2016-01-01T00:00:00.000-0500
# 69757   2016-01-01T00:00:00.000-0500
# 69758   2016-01-01T00:00:00.000-0500
# ...                              ...
# 166566  2016-12-31T00:00:00.000-0500
# 166567  2016-12-31T00:00:00.000-0500
# 166568  2016-12-31T00:00:00.000-0500
# 166569  2016-12-31T00:00:00.000-0500
# 166570  2016-12-31T00:00:00.000-0500
# 166571  2016-12-31T00:00:00.000-0500
# 166572  2016-12-31T00:00:00.000-0500
# 166573  2016-12-31T00:00:00.000-0500
# 166574  2016-12-31T00:00:00.000-0500
# 166575  2016-12-31T00:00:00.000-0500
# 166576  2016-12-31T00:00:00.000-0500
# 166577  2016-12-31T00:00:00.000-0500
# 166578  2016-12-31T00:00:00.000-0500
# 166579  2016-12-31T00:00:00.000-0500
# 166580  2016-12-31T00:00:00.000-0500
# 166581  2016-12-31T00:00:00.000-0500
# 166582  2016-12-31T00:00:00.000-0500
# 166583  2016-12-31T00:00:00.000-0500
# 166584  2016-12-31T00:00:00.000-0500
# 166585  2016-12-31T00:00:00.000-0500
# 166586  2016-12-31T00:00:00.000-0500
# 166587  2016-12-31T00:00:00.000-0500
# 166588  2016-12-31T00:00:00.000-0500
# 166589  2016-12-31T00:00:00.000-0500
# 166590  2016-12-31T00:00:00.000-0500
# 166591  2016-12-31T00:00:00.000-0500
# 166592  2016-12-31T00:00:00.000-0500
# 166593  2016-12-31T00:00:00.000-0500
# 166594  2016-12-31T00:00:00.000-0500
# 166595  2016-12-31T00:00:00.000-0500
#
#                                               metric_name  metric_value
# 69729                 google.accounts:apps_total_licenses             0
# 69730                  google.accounts:apps_used_licenses             0
# 69731                     google.accounts:authorized_apps             0
# 69732           google.accounts:coordinate_total_licenses             0
# 69733              google.accounts:drive_used_quota_in_mb      24642609
# 69734              google.accounts:gmail_used_quota_in_mb      51830831
# 69735       google.accounts:gplus_photos_used_quota_in_mb        912760
# 69736                     google.accounts:num_1day_logins          6602
# 69737                    google.accounts:num_30day_logins         23495
# 69738                     google.accounts:num_7day_logins         14050
# 69739                 google.accounts:num_authorized_apps          2407
# 69740                google.accounts:num_delegated_admins            29
# 69741               google.accounts:num_disabled_accounts         41730
# 69742                    google.accounts:num_locked_users             0
# 69743                   google.accounts:num_security_keys             0
# 69744                    google.accounts:num_super_admins            13
# 69745                 google.accounts:num_suspended_users         41730
# 69746                           google.accounts:num_users         74833
# 69747              google.accounts:num_users_2sv_enforced             0
# 69748              google.accounts:num_users_2sv_enrolled             0
# 69749   google.accounts:num_users_2sv_enrolled_and_enf...             0
# 69750          google.accounts:num_users_2sv_not_enforced         74833
# 69751          google.accounts:num_users_2sv_not_enrolled         74833
# 69752   google.accounts:num_users_2sv_not_enrolled_and...         74833
# 69753   google.accounts:num_users_2sv_not_enrolled_but...             0
# 69754   google.accounts:num_users_less_secure_apps_acc...          2067
# 69755   google.accounts:num_users_less_secure_apps_acc...         72766
# 69756          google.accounts:num_users_overridden_names             0
# 69757   google.accounts:num_users_used_quota_lt_50percent          3594
# 69758                   google.accounts:total_quota_in_mb     112425469
# ...                                                   ...           ...
# 166566           google.gmail:num_inbound_rejected_emails         13465
# 166567           google.gmail:num_inbound_rerouted_emails             0
# 166568               google.gmail:num_inbound_spam_emails         34751
# 166569        google.gmail:num_inbound_unencrypted_emails         42869
# 166570         google.gmail:num_outbound_delivered_emails          1982
# 166571         google.gmail:num_outbound_encrypted_emails          3697
# 166572          google.gmail:num_outbound_rejected_emails            39
# 166573          google.gmail:num_outbound_rerouted_emails             0
# 166574       google.gmail:num_outbound_unencrypted_emails           546
# 166575                 google.gplus:num_1day_active_users             9
# 166576                google.gplus:num_30day_active_users           805
# 166577                 google.gplus:num_7day_active_users           103
# 166578                       google.gplus:num_video_calls            26
# 166579               google.gplus:num_video_calls_android            19
# 166580                   google.gplus:num_video_calls_cfm             0
# 166581                   google.gplus:num_video_calls_ios             5
# 166582                   google.gplus:num_video_calls_web             2
# 166583                 google.gplus:num_video_conferences            25
# 166584         google.gplus:num_video_conferences_android            21
# 166585             google.gplus:num_video_conferences_cfm             0
# 166586             google.gplus:num_video_conferences_ios             5
# 166587          google.gplus:num_video_conferences_mobile            24
# 166588             google.gplus:num_video_conferences_web             1
# 166589              google.gplus:total_video_call_minutes           340
# 166590      google.gplus:total_video_call_minutes_android            40
# 166591          google.gplus:total_video_call_minutes_cfm             0
# 166592          google.gplus:total_video_call_minutes_ios            73
# 166593          google.gplus:total_video_call_minutes_web           226
# 166594                             google.sites:num_sites         10434
# 166595                     google.sites:num_sites_created             0
#
# [96867 rows x 3 columns]

# %%
year2016.to_csv('SecondYear.csv')

# %%
year2017 = data[data['time'].str.startswith('2017')]
year2017
# Out:
#                                 time  \
# 166596  2017-01-01T00:00:00.000-0500
# 166597  2017-01-01T00:00:00.000-0500
# 166598  2017-01-01T00:00:00.000-0500
# 166599  2017-01-01T00:00:00.000-0500
# 166600  2017-01-01T00:00:00.000-0500
# 166601  2017-01-01T00:00:00.000-0500
# 166602  2017-01-01T00:00:00.000-0500
# 166603  2017-01-01T00:00:00.000-0500
# 166604  2017-01-01T00:00:00.000-0500
# 166605  2017-01-01T00:00:00.000-0500
# 166606  2017-01-01T00:00:00.000-0500
# 166607  2017-01-01T00:00:00.000-0500
# 166608  2017-01-01T00:00:00.000-0500
# 166609  2017-01-01T00:00:00.000-0500
# 166610  2017-01-01T00:00:00.000-0500
# 166611  2017-01-01T00:00:00.000-0500
# 166612  2017-01-01T00:00:00.000-0500
# 166613  2017-01-01T00:00:00.000-0500
# 166614  2017-01-01T00:00:00.000-0500
# 166615  2017-01-01T00:00:00.000-0500
# 166616  2017-01-01T00:00:00.000-0500
# 166617  2017-01-01T00:00:00.000-0500
# 166618  2017-01-01T00:00:00.000-0500
# 166619  2017-01-01T00:00:00.000-0500
# 166620  2017-01-01T00:00:00.000-0500
# 166621  2017-01-01T00:00:00.000-0500
# 166622  2017-01-01T00:00:00.000-0500
# 166623  2017-01-01T00:00:00.000-0500
# 166624  2017-01-01T00:00:00.000-0500
# 166625  2017-01-01T00:00:00.000-0500
# ...                              ...
# 312172  2017-12-31T00:00:00.000-0500
# 312173  2017-12-31T00:00:00.000-0500
# 312174  2017-12-31T00:00:00.000-0500
# 312175  2017-12-31T00:00:00.000-0500
# 312176  2017-12-31T00:00:00.000-0500
# 312177  2017-12-31T00:00:00.000-0500
# 312178  2017-12-31T00:00:00.000-0500
# 312179  2017-12-31T00:00:00.000-0500
# 312180  2017-12-31T00:00:00.000-0500
# 312181  2017-12-31T00:00:00.000-0500
# 312182  2017-12-31T00:00:00.000-0500
# 312183  2017-12-31T00:00:00.000-0500
# 312184  2017-12-31T00:00:00.000-0500
# 312185  2017-12-31T00:00:00.000-0500
# 312186  2017-12-31T00:00:00.000-0500
# 312187  2017-12-31T00:00:00.000-0500
# 312188  2017-12-31T00:00:00.000-0500
# 312189  2017-12-31T00:00:00.000-0500
# 312190  2017-12-31T00:00:00.000-0500
# 312191  2017-12-31T00:00:00.000-0500
# 312192  2017-12-31T00:00:00.000-0500
# 312193  2017-12-31T00:00:00.000-0500
# 312194  2017-12-31T00:00:00.000-0500
# 312195  2017-12-31T00:00:00.000-0500
# 312196  2017-12-31T00:00:00.000-0500
# 312197  2017-12-31T00:00:00.000-0500
# 312198  2017-12-31T00:00:00.000-0500
# 312199  2017-12-31T00:00:00.000-0500
# 312200  2017-12-31T00:00:00.000-0500
# 312201  2017-12-31T00:00:00.000-0500
#
#                                               metric_name  metric_value
# 166596  google.device_management:num_7day_ios_9_manage...             0
# 166597  google.device_management:num_7day_ios_9_manage...             0
# 166598  google.device_management:num_7day_ios_managed_...             0
# 166599  google.device_management:num_7day_ios_managed_...             0
# 166600  google.device_management:num_7day_total_manage...             0
# 166601  google.device_management:num_7day_total_manage...             0
# 166602  google.device_management:num_total_unmanaged_u...         84217
# 166603           google.device_management:num_total_users         84217
# 166604                 google.gmail:num_1day_active_users         10067
# 166605                   google.gmail:num_1day_imap_users          9054
# 166606                    google.gmail:num_1day_pop_users            21
# 166607                google.gmail:num_1day_webmail_users          3565
# 166608                google.gmail:num_30day_active_users         26265
# 166609                  google.gmail:num_30day_imap_users         12259
# 166610                   google.gmail:num_30day_pop_users            50
# 166611               google.gmail:num_30day_webmail_users         22553
# 166612                 google.gmail:num_7day_active_users         19012
# 166613                   google.gmail:num_7day_imap_users         10339
# 166614                    google.gmail:num_7day_pop_users            29
# 166615                google.gmail:num_7day_webmail_users         10078
# 166616                  google.gmail:num_emails_exchanged        107427
# 166617                   google.gmail:num_emails_received        104366
# 166618                       google.gmail:num_emails_sent          3061
# 166619          google.gmail:num_inbound_delivered_emails         94236
# 166620          google.gmail:num_inbound_encrypted_emails         52935
# 166621           google.gmail:num_inbound_non_spam_emails         79117
# 166622           google.gmail:num_inbound_rejected_emails         13286
# 166623           google.gmail:num_inbound_rerouted_emails             0
# 166624               google.gmail:num_inbound_spam_emails         28092
# 166625        google.gmail:num_inbound_unencrypted_emails         54274
# ...                                                   ...           ...
# 312172                google.gplus:num_collections_public            21
# 312173                       google.gplus:num_communities           218
# 312174  google.gplus:num_communities_organization_private           135
# 312175     google.gplus:num_communities_organization_wide            22
# 312176               google.gplus:num_communities_private            50
# 312177                google.gplus:num_communities_public            11
# 312178                         google.gplus:num_new_users             0
# 312179                          google.gplus:num_plusones             0
# 312180                           google.gplus:num_replies             0
# 312181                          google.gplus:num_reshares             0
# 312182                            google.gplus:num_shares             0
# 312183                 google.gplus:num_stream_items_read             0
# 312184                       google.gplus:num_video_calls            23
# 312185               google.gplus:num_video_calls_android             1
# 312186                   google.gplus:num_video_calls_cfm             0
# 312187                   google.gplus:num_video_calls_ios            14
# 312188                   google.gplus:num_video_calls_web             4
# 312189                 google.gplus:num_video_conferences            22
# 312190         google.gplus:num_video_conferences_android             9
# 312191             google.gplus:num_video_conferences_cfm             0
# 312192             google.gplus:num_video_conferences_ios            14
# 312193          google.gplus:num_video_conferences_mobile            15
# 312194             google.gplus:num_video_conferences_web             4
# 312195              google.gplus:total_video_call_minutes           921
# 312196      google.gplus:total_video_call_minutes_android             0
# 312197          google.gplus:total_video_call_minutes_cfm             0
# 312198          google.gplus:total_video_call_minutes_ios           415
# 312199          google.gplus:total_video_call_minutes_web           183
# 312200                             google.sites:num_sites         10743
# 312201                     google.sites:num_sites_created             0
#
# [145606 rows x 3 columns]

# %%
year2017.to_csv('ThirdYear.csv')

# %%
year2018 = data[data['time'].str.startswith('2018')]
year2018
# Out:
#                                 time  \
# 312202  2018-01-01T00:00:00.000-0500
# 312203  2018-01-01T00:00:00.000-0500
# 312204  2018-01-01T00:00:00.000-0500
# 312205  2018-01-01T00:00:00.000-0500
# 312206  2018-01-01T00:00:00.000-0500
# 312207  2018-01-01T00:00:00.000-0500
# 312208  2018-01-01T00:00:00.000-0500
# 312209  2018-01-01T00:00:00.000-0500
# 312210  2018-01-01T00:00:00.000-0500
# 312211  2018-01-01T00:00:00.000-0500
# 312212  2018-01-01T00:00:00.000-0500
# 312213  2018-01-01T00:00:00.000-0500
# 312214  2018-01-01T00:00:00.000-0500
# 312215  2018-01-01T00:00:00.000-0500
# 312216  2018-01-01T00:00:00.000-0500
# 312217  2018-01-01T00:00:00.000-0500
# 312218  2018-01-01T00:00:00.000-0500
# 312219  2018-01-01T00:00:00.000-0500
# 312220  2018-01-01T00:00:00.000-0500
# 312221  2018-01-01T00:00:00.000-0500
# 312222  2018-01-01T00:00:00.000-0500
# 312223  2018-01-01T00:00:00.000-0500
# 312224  2018-01-01T00:00:00.000-0500
# 312225  2018-01-01T00:00:00.000-0500
# 312226  2018-01-01T00:00:00.000-0500
# 312227  2018-01-01T00:00:00.000-0500
# 312228  2018-01-01T00:00:00.000-0500
# 312229  2018-01-01T00:00:00.000-0500
# 312230  2018-01-01T00:00:00.000-0500
# 312231  2018-01-01T00:00:00.000-0500
# ...                              ...
# 491447  2018-12-31T00:00:00.000-0500
# 491448  2018-12-31T00:00:00.000-0500
# 491449  2018-12-31T00:00:00.000-0500
# 491450  2018-12-31T00:00:00.000-0500
# 491451  2018-12-31T00:00:00.000-0500
# 491452  2018-12-31T00:00:00.000-0500
# 491453  2018-12-31T00:00:00.000-0500
# 491454  2018-12-31T00:00:00.000-0500
# 491455  2018-12-31T00:00:00.000-0500
# 491456  2018-12-31T00:00:00.000-0500
# 491457  2018-12-31T00:00:00.000-0500
# 491458  2018-12-31T00:00:00.000-0500
# 491459  2018-12-31T00:00:00.000-0500
# 491460  2018-12-31T00:00:00.000-0500
# 491461  2018-12-31T00:00:00.000-0500
# 491462  2018-12-31T00:00:00.000-0500
# 491463  2018-12-31T00:00:00.000-0500
# 491464  2018-12-31T00:00:00.000-0500
# 491465  2018-12-31T00:00:00.000-0500
# 491466  2018-12-31T00:00:00.000-0500
# 491467  2018-12-31T00:00:00.000-0500
# 491468  2018-12-31T00:00:00.000-0500
# 491469  2018-12-31T00:00:00.000-0500
# 491470  2018-12-31T00:00:00.000-0500
# 491471  2018-12-31T00:00:00.000-0500
# 491472  2018-12-31T00:00:00.000-0500
# 491473  2018-12-31T00:00:00.000-0500
# 491474  2018-12-31T00:00:00.000-0500
# 491475  2018-12-31T00:00:00.000-0500
# 491476  2018-12-31T00:00:00.000-0500
#
#                                               metric_name  metric_value
# 312202           google.apps_scripts:num_1day_active_apps            82
# 312203          google.apps_scripts:num_1day_active_users           376
# 312204  google.device_management:num_30day_ios_10_mana...             0
# 312205  google.device_management:num_30day_ios_10_mana...             0
# 312206  google.device_management:num_30day_ios_11_mana...             0
# 312207  google.device_management:num_30day_ios_11_mana...             0
# 312208  google.device_management:num_30day_ios_2_manag...             0
# 312209  google.device_management:num_30day_ios_2_manag...             0
# 312210  google.device_management:num_30day_ios_3_manag...             0
# 312211  google.device_management:num_30day_ios_3_manag...             0
# 312212  google.device_management:num_30day_ios_4_manag...             0
# 312213  google.device_management:num_30day_ios_4_manag...             0
# 312214  google.device_management:num_30day_ios_5_manag...             0
# 312215  google.device_management:num_30day_ios_5_manag...             0
# 312216  google.device_management:num_30day_ios_6_manag...             0
# 312217  google.device_management:num_30day_ios_6_manag...             0
# 312218  google.device_management:num_30day_ios_7_manag...             0
# 312219  google.device_management:num_30day_ios_7_manag...             0
# 312220  google.device_management:num_30day_ios_8_manag...             0
# 312221  google.device_management:num_30day_ios_8_manag...             0
# 312222  google.device_management:num_30day_ios_9_manag...             0
# 312223  google.device_management:num_30day_ios_9_manag...             0
# 312224  google.device_management:num_30day_ios_managed...             0
# 312225  google.device_management:num_30day_ios_managed...             0
# 312226  google.device_management:num_30day_total_manag...             0
# 312227  google.device_management:num_30day_total_manag...             0
# 312228  google.device_management:num_7day_android_2_1_...             0
# 312229  google.device_management:num_7day_android_2_1_...             0
# 312230  google.device_management:num_7day_android_2_2_...             0
# 312231  google.device_management:num_7day_android_2_2_...             0
# ...                                                   ...           ...
# 491447                google.gplus:num_collections_public            26
# 491448                       google.gplus:num_communities           245
# 491449  google.gplus:num_communities_organization_private           153
# 491450     google.gplus:num_communities_organization_wide            27
# 491451               google.gplus:num_communities_private            52
# 491452                google.gplus:num_communities_public            13
# 491453                         google.gplus:num_new_users             0
# 491454                          google.gplus:num_plusones             0
# 491455                           google.gplus:num_replies             0
# 491456                          google.gplus:num_reshares             0
# 491457                            google.gplus:num_shares             0
# 491458                 google.gplus:num_stream_items_read             4
# 491459                       google.gplus:num_video_calls            34
# 491460               google.gplus:num_video_calls_android             2
# 491461                   google.gplus:num_video_calls_cfm             0
# 491462                   google.gplus:num_video_calls_ios            14
# 491463                   google.gplus:num_video_calls_web            18
# 491464                 google.gplus:num_video_conferences            22
# 491465         google.gplus:num_video_conferences_android             7
# 491466             google.gplus:num_video_conferences_cfm             0
# 491467             google.gplus:num_video_conferences_ios            13
# 491468          google.gplus:num_video_conferences_mobile            16
# 491469             google.gplus:num_video_conferences_web            12
# 491470              google.gplus:total_video_call_minutes          2497
# 491471      google.gplus:total_video_call_minutes_android            19
# 491472          google.gplus:total_video_call_minutes_cfm             0
# 491473          google.gplus:total_video_call_minutes_ios           483
# 491474          google.gplus:total_video_call_minutes_web          1994
# 491475                             google.sites:num_sites         11035
# 491476                     google.sites:num_sites_created             0
#
# [179275 rows x 3 columns]

# %%
year2018.to_csv('FourthYear.csv')

# %%
year2019 = data[data['time'].str.startswith('2019')]
year2019
# Out:
#                                 time  \
# 491477  2019-01-01T00:00:00.000-0500
# 491478  2019-01-01T00:00:00.000-0500
# 491479  2019-01-01T00:00:00.000-0500
# 491480  2019-01-01T00:00:00.000-0500
# 491481  2019-01-01T00:00:00.000-0500
# 491482  2019-01-01T00:00:00.000-0500
# 491483  2019-01-01T00:00:00.000-0500
# 491484  2019-01-01T00:00:00.000-0500
# 491485  2019-01-01T00:00:00.000-0500
# 491486  2019-01-01T00:00:00.000-0500
# 491487  2019-01-01T00:00:00.000-0500
# 491488  2019-01-01T00:00:00.000-0500
# 491489  2019-01-01T00:00:00.000-0500
# 491490  2019-01-01T00:00:00.000-0500
# 491491  2019-01-01T00:00:00.000-0500
# 491492  2019-01-01T00:00:00.000-0500
# 491493  2019-01-01T00:00:00.000-0500
# 491494  2019-01-01T00:00:00.000-0500
# 491495  2019-01-01T00:00:00.000-0500
# 491496  2019-01-01T00:00:00.000-0500
# 491497  2019-01-01T00:00:00.000-0500
# 491498  2019-01-01T00:00:00.000-0500
# 491499  2019-01-01T00:00:00.000-0500
# 491500  2019-01-01T00:00:00.000-0500
# 491501  2019-01-01T00:00:00.000-0500
# 491502  2019-01-01T00:00:00.000-0500
# 491503  2019-01-01T00:00:00.000-0500
# 491504  2019-01-01T00:00:00.000-0500
# 491505  2019-01-01T00:00:00.000-0500
# 491506  2019-01-01T00:00:00.000-0500
# ...                              ...
# 611883  2019-08-17T00:00:00.000-0400
# 611884  2019-08-17T00:00:00.000-0400
# 611885  2019-08-17T00:00:00.000-0400
# 611886  2019-08-17T00:00:00.000-0400
# 611887  2019-08-17T00:00:00.000-0400
# 611888  2019-08-17T00:00:00.000-0400
# 611889  2019-08-17T00:00:00.000-0400
# 611890  2019-08-17T00:00:00.000-0400
# 611891  2019-08-17T00:00:00.000-0400
# 611892  2019-08-17T00:00:00.000-0400
# 611893  2019-08-17T00:00:00.000-0400
# 611894  2019-08-17T00:00:00.000-0400
# 611895  2019-08-17T00:00:00.000-0400
# 611896  2019-08-17T00:00:00.000-0400
# 611897  2019-08-17T00:00:00.000-0400
# 611898  2019-08-17T00:00:00.000-0400
# 611899  2019-08-17T00:00:00.000-0400
# 611900  2019-08-17T00:00:00.000-0400
# 611901  2019-08-17T00:00:00.000-0400
# 611902  2019-08-17T00:00:00.000-0400
# 611903  2019-08-17T00:00:00.000-0400
# 611904  2019-08-17T00:00:00.000-0400
# 611905  2019-08-17T00:00:00.000-0400
# 611906  2019-08-17T00:00:00.000-0400
# 611907  2019-08-17T00:00:00.000-0400
# 611908  2019-08-17T00:00:00.000-0400
# 611909  2019-08-17T00:00:00.000-0400
# 611910  2019-08-17T00:00:00.000-0400
# 611911  2019-08-17T00:00:00.000-0400
# 611912  2019-08-17T00:00:00.000-0400
#
#                                               metric_name  metric_value
# 491477                                     google._empty_             0
# 491478                    google.accounts:authorized_apps             0
# 491479             google.accounts:drive_used_quota_in_mb     154627215
# 491480             google.accounts:gmail_used_quota_in_mb      82637988
# 491481      google.accounts:gplus_photos_used_quota_in_mb       2418609
# 491482                    google.accounts:num_1day_logins          2366
# 491483                   google.accounts:num_30day_logins         21519
# 491484                    google.accounts:num_7day_logins          8894
# 491485                 google.accounts:num_archived_users             0
# 491486                google.accounts:num_authorized_apps          3513
# 491487               google.accounts:num_delegated_admins            34
# 491488              google.accounts:num_disabled_accounts         72650
# 491489                   google.accounts:num_locked_users             1
# 491490                  google.accounts:num_security_keys             4
# 491491                   google.accounts:num_super_admins            14
# 491492                google.accounts:num_suspended_users         72649
# 491493                          google.accounts:num_users        102230
# 491494             google.accounts:num_users_2sv_enforced             0
# 491495             google.accounts:num_users_2sv_enrolled           197
# 491496  google.accounts:num_users_2sv_enrolled_and_enf...             0
# 491497         google.accounts:num_users_2sv_not_enforced        102230
# 491498         google.accounts:num_users_2sv_not_enrolled        102033
# 491499  google.accounts:num_users_2sv_not_enrolled_and...        102033
# 491500  google.accounts:num_users_2sv_not_enrolled_but...             0
# 491501  google.accounts:num_users_less_secure_apps_acc...           905
# 491502  google.accounts:num_users_less_secure_apps_acc...        101325
# 491503         google.accounts:num_users_overridden_names             0
# 491504  google.accounts:num_users_used_quota_lt_50percent          3594
# 491505        google.accounts:team_drive_used_quota_in_mb       2887125
# 491506                  google.accounts:total_quota_in_mb     112398075
# ...                                                   ...           ...
# 611883                           google.meet:num_meetings             0
# 611884                   google.meet:num_meetings_android             0
# 611885                google.meet:num_meetings_chromebase             0
# 611886                 google.meet:num_meetings_chromebox             0
# 611887                       google.meet:num_meetings_ios             0
# 611888                  google.meet:num_meetings_jamboard             0
# 611889            google.meet:num_meetings_unknown_client             0
# 611890                       google.meet:num_meetings_web             0
# 611891       google.meet:num_meetings_with_11_to_15_calls             0
# 611892       google.meet:num_meetings_with_16_to_25_calls             0
# 611893       google.meet:num_meetings_with_26_to_50_calls             0
# 611894              google.meet:num_meetings_with_2_calls             0
# 611895         google.meet:num_meetings_with_3_to_5_calls             0
# 611896        google.meet:num_meetings_with_6_to_10_calls             0
# 611897       google.meet:num_meetings_with_external_users             0
# 611898        google.meet:num_meetings_with_pstn_in_users             0
# 611899       google.meet:num_meetings_with_pstn_out_users             0
# 611900                     google.meet:total_call_minutes             0
# 611901             google.meet:total_call_minutes_android             0
# 611902   google.meet:total_call_minutes_by_external_users             0
# 611903   google.meet:total_call_minutes_by_internal_users             0
# 611904    google.meet:total_call_minutes_by_pstn_in_users             0
# 611905   google.meet:total_call_minutes_by_pstn_out_users             0
# 611906          google.meet:total_call_minutes_chromebase             0
# 611907           google.meet:total_call_minutes_chromebox             0
# 611908                 google.meet:total_call_minutes_ios             0
# 611909            google.meet:total_call_minutes_jamboard             0
# 611910      google.meet:total_call_minutes_unknown_client             0
# 611911                 google.meet:total_call_minutes_web             0
# 611912                  google.meet:total_meeting_minutes             0
#
# [120436 rows x 3 columns]

# %%
year2019.to_csv('FifthYear.csv')
