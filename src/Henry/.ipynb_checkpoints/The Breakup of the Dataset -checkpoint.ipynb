# %% [markdown]
# Seperating the G-suite data into there respective services and uploading them as a csv file

# %%
from datetime import datetime
from dateutil.parser import parse

import pandas as pd
data_path = "C:\\Users\\Henry\\Documents\\405-DataScience\\G_Suite_Metrics-Gsuite_Henry\\data\\dataset.csv"
data = pd.read_csv(data_path)
data_path_write = 'C:\\Users\\Henry\\Documents\\405-DataScience\\G_Suite_Metrics\\data\\Services\\'

# %% [markdown]
# Passing the column 'time' through to_datetime

# %%
data['time'] = pd.to_datetime(data.time)

# %% [markdown]
# Seperations begin below

# %%
google_accounts = data[data['metric_name'].str.startswith('google.accounts')]
google_accounts
# Out:
#                              time  \
# 0       2015-03-23 00:00:00-04:00
# 1       2015-03-23 00:00:00-04:00
# 2       2015-03-23 00:00:00-04:00
# 3       2015-03-23 00:00:00-04:00
# 4       2015-03-23 00:00:00-04:00
# 5       2015-03-23 00:00:00-04:00
# 6       2015-03-23 00:00:00-04:00
# 7       2015-03-23 00:00:00-04:00
# 8       2015-03-23 00:00:00-04:00
# 9       2015-03-23 00:00:00-04:00
# 10      2015-03-23 00:00:00-04:00
# 11      2015-03-23 00:00:00-04:00
# 12      2015-03-23 00:00:00-04:00
# 13      2015-03-23 00:00:00-04:00
# 14      2015-03-23 00:00:00-04:00
# 15      2015-03-23 00:00:00-04:00
# 16      2015-03-23 00:00:00-04:00
# 17      2015-03-23 00:00:00-04:00
# 18      2015-03-23 00:00:00-04:00
# 19      2015-03-23 00:00:00-04:00
# 20      2015-03-23 00:00:00-04:00
# 21      2015-03-23 00:00:00-04:00
# 22      2015-03-23 00:00:00-04:00
# 23      2015-03-23 00:00:00-04:00
# 24      2015-03-23 00:00:00-04:00
# 25      2015-03-23 00:00:00-04:00
# ...

# %%
google_gmail = data[data['metric_name'].str.startswith('google.gmail')]
google_gmail
# Out:
#                              time  \
# 214     2015-03-23 00:00:00-04:00
# 215     2015-03-23 00:00:00-04:00
# 216     2015-03-23 00:00:00-04:00
# 217     2015-03-23 00:00:00-04:00
# 218     2015-03-23 00:00:00-04:00
# 219     2015-03-23 00:00:00-04:00
# 220     2015-03-23 00:00:00-04:00
# 221     2015-03-23 00:00:00-04:00
# 222     2015-03-23 00:00:00-04:00
# 223     2015-03-23 00:00:00-04:00
# 224     2015-03-23 00:00:00-04:00
# 225     2015-03-23 00:00:00-04:00
# 226     2015-03-23 00:00:00-04:00
# 227     2015-03-23 00:00:00-04:00
# 228     2015-03-23 00:00:00-04:00
# 229     2015-03-23 00:00:00-04:00
# 230     2015-03-23 00:00:00-04:00
# 231     2015-03-23 00:00:00-04:00
# 232     2015-03-23 00:00:00-04:00
# 233     2015-03-23 00:00:00-04:00
# 234     2015-03-23 00:00:00-04:00
# 235     2015-03-23 00:00:00-04:00
# 236     2015-03-23 00:00:00-04:00
# 237     2015-03-23 00:00:00-04:00
# 238     2015-03-23 00:00:00-04:00
# 239     2015-03-23 00:00:00-04:00
# ...

# %%
google_docs = data[data['metric_name'].str.startswith('google.docs')]
google_docs
# Out:
#                              time  \
# 175     2015-03-23 00:00:00-04:00
# 176     2015-03-23 00:00:00-04:00
# 177     2015-03-23 00:00:00-04:00
# 178     2015-03-23 00:00:00-04:00
# 179     2015-03-23 00:00:00-04:00
# 180     2015-03-23 00:00:00-04:00
# 181     2015-03-23 00:00:00-04:00
# 182     2015-03-23 00:00:00-04:00
# 183     2015-03-23 00:00:00-04:00
# 184     2015-03-23 00:00:00-04:00
# 185     2015-03-23 00:00:00-04:00
# 186     2015-03-23 00:00:00-04:00
# 187     2015-03-23 00:00:00-04:00
# 188     2015-03-23 00:00:00-04:00
# 189     2015-03-23 00:00:00-04:00
# 190     2015-03-23 00:00:00-04:00
# 191     2015-03-23 00:00:00-04:00
# 192     2015-03-23 00:00:00-04:00
# 193     2015-03-23 00:00:00-04:00
# 194     2015-03-23 00:00:00-04:00
# 195     2015-03-23 00:00:00-04:00
# 196     2015-03-23 00:00:00-04:00
# 197     2015-03-23 00:00:00-04:00
# 198     2015-03-23 00:00:00-04:00
# 199     2015-03-23 00:00:00-04:00
# 200     2015-03-23 00:00:00-04:00
# ...

# %%
google_calender = data[data['metric_name'].str.startswith('google.calendar')]
google_calender
# Out:
#                              time                             metric_name  \
# 28      2015-03-23 00:00:00-04:00   google.calendar:num_1day_active_users
# 29      2015-03-23 00:00:00-04:00  google.calendar:num_30day_active_users
# 30      2015-03-23 00:00:00-04:00   google.calendar:num_7day_active_users
# 277     2015-03-24 00:00:00-04:00   google.calendar:num_1day_active_users
# 278     2015-03-24 00:00:00-04:00  google.calendar:num_30day_active_users
# 279     2015-03-24 00:00:00-04:00   google.calendar:num_7day_active_users
# 526     2015-03-25 00:00:00-04:00   google.calendar:num_1day_active_users
# 527     2015-03-25 00:00:00-04:00  google.calendar:num_30day_active_users
# 528     2015-03-25 00:00:00-04:00   google.calendar:num_7day_active_users
# 775     2015-03-26 00:00:00-04:00   google.calendar:num_1day_active_users
# 776     2015-03-26 00:00:00-04:00  google.calendar:num_30day_active_users
# 777     2015-03-26 00:00:00-04:00   google.calendar:num_7day_active_users
# ...

# %%
google_sites = data[data['metric_name'].str.startswith('google.sites')]
google_sites
# Out:
#                              time                     metric_name  \
# 247     2015-03-23 00:00:00-04:00          google.sites:num_sites
# 248     2015-03-23 00:00:00-04:00  google.sites:num_sites_created
# 496     2015-03-24 00:00:00-04:00          google.sites:num_sites
# 497     2015-03-24 00:00:00-04:00  google.sites:num_sites_created
# 745     2015-03-25 00:00:00-04:00          google.sites:num_sites
# 746     2015-03-25 00:00:00-04:00  google.sites:num_sites_created
# 994     2015-03-26 00:00:00-04:00          google.sites:num_sites
# 995     2015-03-26 00:00:00-04:00  google.sites:num_sites_created
# 1243    2015-03-27 00:00:00-04:00          google.sites:num_sites
# 1244    2015-03-27 00:00:00-04:00  google.sites:num_sites_created
# 1492    2015-03-28 00:00:00-04:00          google.sites:num_sites
# 1493    2015-03-28 00:00:00-04:00  google.sites:num_sites_created
# 1741    2015-03-29 00:00:00-04:00          google.sites:num_sites
# ...

# %%
google_drive =  data[data['metric_name'].str.startswith('google.drive')]
google_drive
# Out:
#                              time  \
# 186868  2017-03-12 00:00:00-05:00
# 186869  2017-03-12 00:00:00-05:00
# 186870  2017-03-12 00:00:00-05:00
# 186871  2017-03-12 00:00:00-05:00
# 186872  2017-03-12 00:00:00-05:00
# 186873  2017-03-12 00:00:00-05:00
# 186874  2017-03-12 00:00:00-05:00
# 186875  2017-03-12 00:00:00-05:00
# 186876  2017-03-12 00:00:00-05:00
# 186877  2017-03-12 00:00:00-05:00
# 186878  2017-03-12 00:00:00-05:00
# 186879  2017-03-12 00:00:00-05:00
# 186880  2017-03-12 00:00:00-05:00
# 186881  2017-03-12 00:00:00-05:00
# 186882  2017-03-12 00:00:00-05:00
# 186883  2017-03-12 00:00:00-05:00
# 186884  2017-03-12 00:00:00-05:00
# 186885  2017-03-12 00:00:00-05:00
# 186886  2017-03-12 00:00:00-05:00
# 186887  2017-03-12 00:00:00-05:00
# 186888  2017-03-12 00:00:00-05:00
# 186889  2017-03-12 00:00:00-05:00
# 186890  2017-03-12 00:00:00-05:00
# 186891  2017-03-12 00:00:00-05:00
# 186892  2017-03-12 00:00:00-05:00
# 186893  2017-03-12 00:00:00-05:00
# ...

# %%
google_meet = data[data['metric_name'].str.startswith('google.meet')]
google_meet
# Out:
#                              time  \
# 318219  2018-01-14 00:00:00-05:00
# 318220  2018-01-14 00:00:00-05:00
# 318221  2018-01-14 00:00:00-05:00
# 318222  2018-01-14 00:00:00-05:00
# 318223  2018-01-14 00:00:00-05:00
# 318224  2018-01-14 00:00:00-05:00
# 318225  2018-01-14 00:00:00-05:00
# 318226  2018-01-14 00:00:00-05:00
# 318227  2018-01-14 00:00:00-05:00
# 318228  2018-01-14 00:00:00-05:00
# 318229  2018-01-14 00:00:00-05:00
# 318230  2018-01-14 00:00:00-05:00
# 318231  2018-01-14 00:00:00-05:00
# 318232  2018-01-14 00:00:00-05:00
# 318233  2018-01-14 00:00:00-05:00
# 318234  2018-01-14 00:00:00-05:00
# 318235  2018-01-14 00:00:00-05:00
# 318236  2018-01-14 00:00:00-05:00
# 318237  2018-01-14 00:00:00-05:00
# 318238  2018-01-14 00:00:00-05:00
# 318239  2018-01-14 00:00:00-05:00
# 318240  2018-01-14 00:00:00-05:00
# 318241  2018-01-14 00:00:00-05:00
# 318242  2018-01-14 00:00:00-05:00
# 318243  2018-01-14 00:00:00-05:00
# 318244  2018-01-14 00:00:00-05:00
# ...

# %%
google_class = data[data['metric_name'].str.startswith('google.classroom')]
google_class
# Out:
#                              time                                 metric_name  \
# 190819  2017-03-26 00:00:00-04:00   google.classroom:num_14day_active_courses
# 190820  2017-03-26 00:00:00-04:00          google.classroom:num_1day_students
# 190821  2017-03-26 00:00:00-04:00          google.classroom:num_1day_teachers
# 190822  2017-03-26 00:00:00-04:00             google.classroom:num_1day_users
# 190823  2017-03-26 00:00:00-04:00         google.classroom:num_30day_students
# 190824  2017-03-26 00:00:00-04:00         google.classroom:num_30day_teachers
# 190825  2017-03-26 00:00:00-04:00            google.classroom:num_30day_users
# 190826  2017-03-26 00:00:00-04:00          google.classroom:num_7day_students
# 190827  2017-03-26 00:00:00-04:00          google.classroom:num_7day_teachers
# 190828  2017-03-26 00:00:00-04:00             google.classroom:num_7day_users
# 190829  2017-03-26 00:00:00-04:00        google.classroom:num_courses_created
# ...

# %%
google_docs = data[data['metric_name'].str.startswith('google.docs')]
google_docs
# Out:
#                              time  \
# 175     2015-03-23 00:00:00-04:00
# 176     2015-03-23 00:00:00-04:00
# 177     2015-03-23 00:00:00-04:00
# 178     2015-03-23 00:00:00-04:00
# 179     2015-03-23 00:00:00-04:00
# 180     2015-03-23 00:00:00-04:00
# 181     2015-03-23 00:00:00-04:00
# 182     2015-03-23 00:00:00-04:00
# 183     2015-03-23 00:00:00-04:00
# 184     2015-03-23 00:00:00-04:00
# 185     2015-03-23 00:00:00-04:00
# 186     2015-03-23 00:00:00-04:00
# 187     2015-03-23 00:00:00-04:00
# 188     2015-03-23 00:00:00-04:00
# 189     2015-03-23 00:00:00-04:00
# 190     2015-03-23 00:00:00-04:00
# 191     2015-03-23 00:00:00-04:00
# 192     2015-03-23 00:00:00-04:00
# 193     2015-03-23 00:00:00-04:00
# 194     2015-03-23 00:00:00-04:00
# 195     2015-03-23 00:00:00-04:00
# 196     2015-03-23 00:00:00-04:00
# 197     2015-03-23 00:00:00-04:00
# 198     2015-03-23 00:00:00-04:00
# 199     2015-03-23 00:00:00-04:00
# 200     2015-03-23 00:00:00-04:00
# ...

# %%
google_app =  data[data['metric_name'].str.startswith('google.app')]
google_app
# Out:
#                              time                                metric_name  \
# 234369  2017-07-04 00:00:00-04:00      google.app_maker:num_1day_active_apps
# 234370  2017-07-04 00:00:00-04:00     google.app_maker:num_1day_active_users
# 234371  2017-07-04 00:00:00-04:00   google.apps_scripts:num_1day_active_apps
# 234372  2017-07-04 00:00:00-04:00  google.apps_scripts:num_1day_active_users
# 234641  2017-07-05 00:00:00-04:00      google.app_maker:num_1day_active_apps
# 234642  2017-07-05 00:00:00-04:00     google.app_maker:num_1day_active_users
# 234643  2017-07-05 00:00:00-04:00   google.apps_scripts:num_1day_active_apps
# 234644  2017-07-05 00:00:00-04:00  google.apps_scripts:num_1day_active_users
# 235095  2017-07-06 00:00:00-04:00      google.app_maker:num_1day_active_apps
# 235096  2017-07-06 00:00:00-04:00     google.app_maker:num_1day_active_users
# 235097  2017-07-06 00:00:00-04:00   google.apps_scripts:num_1day_active_apps
# ...

# %%
google_device = data[data['metric_name'].str.startswith('google.device')]
google_device
# Out:
#                              time  \
# 31      2015-03-23 00:00:00-04:00
# 32      2015-03-23 00:00:00-04:00
# 33      2015-03-23 00:00:00-04:00
# 34      2015-03-23 00:00:00-04:00
# 35      2015-03-23 00:00:00-04:00
# 36      2015-03-23 00:00:00-04:00
# 37      2015-03-23 00:00:00-04:00
# 38      2015-03-23 00:00:00-04:00
# 39      2015-03-23 00:00:00-04:00
# 40      2015-03-23 00:00:00-04:00
# 41      2015-03-23 00:00:00-04:00
# 42      2015-03-23 00:00:00-04:00
# 43      2015-03-23 00:00:00-04:00
# 44      2015-03-23 00:00:00-04:00
# 45      2015-03-23 00:00:00-04:00
# 46      2015-03-23 00:00:00-04:00
# 47      2015-03-23 00:00:00-04:00
# 48      2015-03-23 00:00:00-04:00
# 49      2015-03-23 00:00:00-04:00
# 50      2015-03-23 00:00:00-04:00
# 51      2015-03-23 00:00:00-04:00
# 52      2015-03-23 00:00:00-04:00
# 53      2015-03-23 00:00:00-04:00
# 54      2015-03-23 00:00:00-04:00
# 55      2015-03-23 00:00:00-04:00
# 56      2015-03-23 00:00:00-04:00
# ...

# %% [markdown]
# Writing the seperated dataframs as a csv file

# %%
google_accounts.to_csv(data_path_write + 'Google_account.csv', index = False)
google_gmail.to_csv(data_path_write + 'Google_gmail.csv', index = False)
google_docs.to_csv(data_path_write + 'Google_docs.csv', index = False)
google_calender.to_csv(data_path_write + 'Google_calender.csv', index = False)
google_app.to_csv(data_path_write + 'Google_app.csv', index = False)
google_class.to_csv(data_path_write + 'Google_class.csv', index = False)
google_meet.to_csv(data_path_write + 'Google_meet.csv', index = False)
google_drive.to_csv(data_path_write + 'Google_drive.csv', index = False)
google_sites.to_csv(data_path_write + 'Google_sites.csv', index = False)
google_device.to_csv(data_path_write + 'Google_Device.csv',index = False)
