# %% [markdown]
# Reading the data set using pandas

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
df = pd.read_csv('gsuite.csv')

# %% [markdown]
# Here head retrieves the first 10 of the data set

# %%
df.head(10)
# Out:
#                            time  \
# 0  2015-03-23T00:00:00.000-0400
# 1  2015-03-23T00:00:00.000-0400
# 2  2015-03-23T00:00:00.000-0400
# 3  2015-03-23T00:00:00.000-0400
# 4  2015-03-23T00:00:00.000-0400
# 5  2015-03-23T00:00:00.000-0400
# 6  2015-03-23T00:00:00.000-0400
# 7  2015-03-23T00:00:00.000-0400
# 8  2015-03-23T00:00:00.000-0400
# 9  2015-03-23T00:00:00.000-0400
#
#                                      metric_name  metric_value
# 0            google.accounts:apps_total_licenses             0
# 1             google.accounts:apps_used_licenses             0
# 2                google.accounts:authorized_apps             0
# 3      google.accounts:coordinate_total_licenses             0
# 4         google.accounts:drive_used_quota_in_mb       9537833
# 5         google.accounts:gmail_used_quota_in_mb      29158045
# 6  google.accounts:gplus_photos_used_quota_in_mb        659544
# 7                google.accounts:num_1day_logins         16814
# 8               google.accounts:num_30day_logins         24022
# 9                google.accounts:num_7day_logins         21763

# %% [markdown]
# Tail gives the last 5 rows in the data set

# %%
df.tail()
# Out:
#                                 time  \
# 611908  2019-08-17T00:00:00.000-0400
# 611909  2019-08-17T00:00:00.000-0400
# 611910  2019-08-17T00:00:00.000-0400
# 611911  2019-08-17T00:00:00.000-0400
# 611912  2019-08-17T00:00:00.000-0400
#
#                                           metric_name  metric_value
# 611908  google.meet:total_call_minutes_unknown_client             0
# 611909             google.meet:total_call_minutes_web             0
# 611910              google.meet:total_meeting_minutes             0
# 611911                         google.sites:num_sites         11130
# 611912                 google.sites:num_sites_created             0

# %% [markdown]
# size gives the total data points rows * columns

# %%
df.size
# Out:
# 1835739

# %% [markdown]
# Shape gives the dimensionality of the data set.

# %%
df.shape
# Out:
# (611913, 3)

# %% [markdown]
# columns gives us the index names and the data type

# %%
df.columns
# Out:
# Index(['time', 'metric_name', 'metric_value'], dtype='object')

# %%
df['metric_name']
# Out:
# 0                       google.accounts:apps_total_licenses
# 1                        google.accounts:apps_used_licenses
# 2                           google.accounts:authorized_apps
# 3                 google.accounts:coordinate_total_licenses
# 4                    google.accounts:drive_used_quota_in_mb
# 5                    google.accounts:gmail_used_quota_in_mb
# 6             google.accounts:gplus_photos_used_quota_in_mb
# 7                           google.accounts:num_1day_logins
# 8                          google.accounts:num_30day_logins
# 9                           google.accounts:num_7day_logins
# 10                      google.accounts:num_authorized_apps
# 11                     google.accounts:num_delegated_admins
# 12                    google.accounts:num_disabled_accounts
# 13                         google.accounts:num_locked_users
# 14                         google.accounts:num_super_admins
# 15                      google.accounts:num_suspended_users
# 16                                google.accounts:num_users
# 17                   google.accounts:num_users_2sv_enforced
# 18                   google.accounts:num_users_2sv_enrolled
# 19        google.accounts:num_users_2sv_enrolled_and_enf...
# 20               google.accounts:num_users_2sv_not_enforced
# 21               google.accounts:num_users_2sv_not_enrolled
# 22        google.accounts:num_users_2sv_not_enrolled_and...
# 23        google.accounts:num_users_2sv_not_enrolled_but...
# 24        google.accounts:num_users_used_quota_lt_50percent
# 25                        google.accounts:total_quota_in_mb
# 26                         google.accounts:used_quota_in_mb
# 27                     google.accounts:vault_total_licenses
# 28                    google.calendar:num_1day_active_users
# 29                   google.calendar:num_30day_active_users
#                                 ...
# 611883                  google.meet:num_meetings_chromebase
# 611884                   google.meet:num_meetings_chromebox
# 611885                         google.meet:num_meetings_ios
# 611886                    google.meet:num_meetings_jamboard
# 611887              google.meet:num_meetings_unknown_client
# 611888                         google.meet:num_meetings_web
# 611889         google.meet:num_meetings_with_11_to_15_calls
# 611890         google.meet:num_meetings_with_16_to_25_calls
# 611891                google.meet:num_meetings_with_2_calls
# 611892         google.meet:num_meetings_with_26_to_50_calls
# 611893           google.meet:num_meetings_with_3_to_5_calls
# 611894          google.meet:num_meetings_with_6_to_10_calls
# 611895         google.meet:num_meetings_with_external_users
# 611896          google.meet:num_meetings_with_pstn_in_users
# 611897         google.meet:num_meetings_with_pstn_out_users
# 611898                       google.meet:total_call_minutes
# 611899               google.meet:total_call_minutes_android
# 611900     google.meet:total_call_minutes_by_external_users
# 611901     google.meet:total_call_minutes_by_internal_users
# 611902      google.meet:total_call_minutes_by_pstn_in_users
# 611903     google.meet:total_call_minutes_by_pstn_out_users
# 611904            google.meet:total_call_minutes_chromebase
# 611905             google.meet:total_call_minutes_chromebox
# 611906                   google.meet:total_call_minutes_ios
# 611907              google.meet:total_call_minutes_jamboard
# 611908        google.meet:total_call_minutes_unknown_client
# 611909                   google.meet:total_call_minutes_web
# 611910                    google.meet:total_meeting_minutes
# 611911                               google.sites:num_sites
# 611912                       google.sites:num_sites_created
# Name: metric_name, Length: 611913, dtype: object

# %% [markdown]
# Gives the two columns metric_name and metric_value.

# %%
df[['metric_name','metric_value']]

# %% [markdown]
# Sorting the values of a column metric_values

# %%
df.sort_values(['metric_value'])
# Out:
#                                 time  \
# 214008  2017-05-18T00:00:00.000-0400
# 214021  2017-05-18T00:00:00.000-0400
# 213993  2017-05-18T00:00:00.000-0400
# 213561  2017-05-17T00:00:00.000-0400
# 562716  2019-05-08T00:00:00.000-0400
# 262954  2017-09-09T00:00:00.000-0400
# 262967  2017-09-09T00:00:00.000-0400
# 262939  2017-09-09T00:00:00.000-0400
# 196115  2017-04-06T00:00:00.000-0400
# 213574  2017-05-17T00:00:00.000-0400
# 213546  2017-05-17T00:00:00.000-0400
# 281784  2017-10-22T00:00:00.000-0400
# 263419  2017-09-10T00:00:00.000-0400
# 263432  2017-09-10T00:00:00.000-0400
# 263404  2017-09-10T00:00:00.000-0400
# 281797  2017-10-22T00:00:00.000-0400
# 281769  2017-10-22T00:00:00.000-0400
# 322318  2018-01-22T00:00:00.000-0500
# 215360  2017-05-21T00:00:00.000-0400
# 583919  2019-06-20T00:00:00.000-0400
# 583891  2019-06-20T00:00:00.000-0400
# 583906  2019-06-20T00:00:00.000-0400
# 215373  2017-05-21T00:00:00.000-0400
# 215345  2017-05-21T00:00:00.000-0400
# 213114  2017-05-16T00:00:00.000-0400
# 213127  2017-05-16T00:00:00.000-0400
# 213099  2017-05-16T00:00:00.000-0400
# 475649  2018-12-03T00:00:00.000-0500
# 372043  2018-05-04T00:00:00.000-0400
# 274822  2017-10-07T00:00:00.000-0400
# ...                              ...
# 596655  2019-07-18T00:00:00.000-0400
# 597076  2019-07-19T00:00:00.000-0400
# 597497  2019-07-20T00:00:00.000-0400
# 597918  2019-07-21T00:00:00.000-0400
# 598504  2019-07-22T00:00:00.000-0400
# 599070  2019-07-23T00:00:00.000-0400
# 599626  2019-07-24T00:00:00.000-0400
# 599948  2019-07-25T00:00:00.000-0400
# 600537  2019-07-26T00:00:00.000-0400
# 601125  2019-07-27T00:00:00.000-0400
# 601545  2019-07-28T00:00:00.000-0400
# 602130  2019-07-29T00:00:00.000-0400
# 602719  2019-07-30T00:00:00.000-0400
# 603305  2019-07-31T00:00:00.000-0400
# 603723  2019-08-02T00:00:00.000-0400
# 604312  2019-08-03T00:00:00.000-0400
# 604901  2019-08-04T00:00:00.000-0400
# 605490  2019-08-05T00:00:00.000-0400
# 606076  2019-08-06T00:00:00.000-0400
# 606665  2019-08-07T00:00:00.000-0400
# 607086  2019-08-08T00:00:00.000-0400
# 607507  2019-08-09T00:00:00.000-0400
# 607928  2019-08-10T00:00:00.000-0400
# 608345  2019-08-11T00:00:00.000-0400
# 608934  2019-08-12T00:00:00.000-0400
# 609355  2019-08-13T00:00:00.000-0400
# 609944  2019-08-14T00:00:00.000-0400
# 610347  2019-08-15T00:00:00.000-0400
# 610765  2019-08-16T00:00:00.000-0400
# 611354  2019-08-17T00:00:00.000-0400
#
#                                               metric_name  metric_value
# 214008  google.drive:num_owned_items_with_visibility_p...       -376732
# 214021           google.drive:num_owned_other_types_delta       -375495
# 213993                 google.drive:num_owned_items_delta       -374954
# 213561  google.drive:num_owned_items_with_visibility_p...       -195240
# 562716  google.drive:num_owned_items_with_visibility_p...       -185944
# 262954  google.drive:num_owned_items_with_visibility_p...       -169071
# 262967           google.drive:num_owned_other_types_delta       -168947
# 262939                 google.drive:num_owned_items_delta       -168422
# 196115  google.drive:num_owned_items_with_visibility_s...       -166899
# 213574           google.drive:num_owned_other_types_delta       -149781
# 213546                 google.drive:num_owned_items_delta       -149439
# 281784  google.drive:num_owned_items_with_visibility_p...       -143804
# 263419  google.drive:num_owned_items_with_visibility_p...       -135518
# 263432           google.drive:num_owned_other_types_delta       -135088
# 263404                 google.drive:num_owned_items_delta       -134192
# 281797           google.drive:num_owned_other_types_delta       -129634
# 281769                 google.drive:num_owned_items_delta       -128305
# 322318  google.drive:num_owned_items_with_visibility_s...       -124010
# 215360  google.drive:num_owned_items_with_visibility_p...       -102223
# 583919           google.drive:num_owned_other_types_delta       -102169
# 583891                 google.drive:num_owned_items_delta       -101289
# 583906  google.drive:num_owned_items_with_visibility_p...       -100352
# 215373           google.drive:num_owned_other_types_delta        -98847
# 215345                 google.drive:num_owned_items_delta        -98630
# 213114  google.drive:num_owned_items_with_visibility_p...        -93072
# 213127           google.drive:num_owned_other_types_delta        -92019
# 213099                 google.drive:num_owned_items_delta        -91631
# 475649  google.drive:num_owned_items_with_visibility_p...        -81822
# 372043  google.drive:num_owned_items_with_visibility_s...        -72361
# 274822  google.drive:num_owned_items_with_visibility_p...        -72170
# ...                                                   ...           ...
# 596655                   google.accounts:used_quota_in_mb     267748074
# 597076                   google.accounts:used_quota_in_mb     267908399
# 597497                   google.accounts:used_quota_in_mb     268629314
# 597918                   google.accounts:used_quota_in_mb     268712439
# 598504                   google.accounts:used_quota_in_mb     268879368
# 599070                   google.accounts:used_quota_in_mb     269130882
# 599626                   google.accounts:used_quota_in_mb     269361367
# 599948                   google.accounts:used_quota_in_mb     269630455
# 600537                   google.accounts:used_quota_in_mb     269717576
# 601125                   google.accounts:used_quota_in_mb     269786737
# 601545                   google.accounts:used_quota_in_mb     269825008
# 602130                   google.accounts:used_quota_in_mb     269877590
# 602719                   google.accounts:used_quota_in_mb     269902519
# 603305                   google.accounts:used_quota_in_mb     270848184
# 603723                   google.accounts:used_quota_in_mb     272237589
# 604312                   google.accounts:used_quota_in_mb     272274896
# 604901                   google.accounts:used_quota_in_mb     272308065
# 605490                   google.accounts:used_quota_in_mb     272746312
# 606076                   google.accounts:used_quota_in_mb     273037185
# 606665                   google.accounts:used_quota_in_mb     273082641
# 607086                   google.accounts:used_quota_in_mb     273174682
# 607507                   google.accounts:used_quota_in_mb     273211159
# 607928                   google.accounts:used_quota_in_mb     273262719
# 608345                   google.accounts:used_quota_in_mb     273278961
# 608934                   google.accounts:used_quota_in_mb     273390919
# 609355                   google.accounts:used_quota_in_mb     273511848
# 609944                   google.accounts:used_quota_in_mb     273677846
# 610347                   google.accounts:used_quota_in_mb     273864978
# 610765                   google.accounts:used_quota_in_mb     273996809
# 611354                   google.accounts:used_quota_in_mb     274032962
#
# [611913 rows x 3 columns]

# %% [markdown]
# Retreiving data set with negative values for number of users

# %%
df.loc[(df.metric_value < 0)]
# Out:
#                                 time  \
# 25      2015-03-23T00:00:00.000-0400
# 274     2015-03-24T00:00:00.000-0400
# 523     2015-03-25T00:00:00.000-0400
# 772     2015-03-26T00:00:00.000-0400
# 1021    2015-03-27T00:00:00.000-0400
# 1270    2015-03-28T00:00:00.000-0400
# 1519    2015-03-29T00:00:00.000-0400
# 1768    2015-03-30T00:00:00.000-0400
# 2017    2015-03-31T00:00:00.000-0400
# 2266    2015-04-01T00:00:00.000-0400
# 2515    2015-04-02T00:00:00.000-0400
# 2764    2015-04-03T00:00:00.000-0400
# 3014    2015-04-04T00:00:00.000-0400
# 3264    2015-04-05T00:00:00.000-0400
# 3514    2015-04-06T00:00:00.000-0400
# 3764    2015-04-07T00:00:00.000-0400
# 4014    2015-04-08T00:00:00.000-0400
# 4264    2015-04-09T00:00:00.000-0400
# 4514    2015-04-10T00:00:00.000-0400
# 4764    2015-04-11T00:00:00.000-0400
# 5014    2015-04-12T00:00:00.000-0400
# 5264    2015-04-13T00:00:00.000-0400
# 5514    2015-04-14T00:00:00.000-0400
# 5764    2015-04-15T00:00:00.000-0400
# 6014    2015-04-16T00:00:00.000-0400
# 6264    2015-04-17T00:00:00.000-0400
# 6514    2015-04-18T00:00:00.000-0400
# 6764    2015-04-19T00:00:00.000-0400
# 7014    2015-04-20T00:00:00.000-0400
# 194751  2017-04-03T00:00:00.000-0400
# ...                              ...
# 592241  2019-07-07T00:00:00.000-0400
# 592821  2019-07-08T00:00:00.000-0400
# 598342  2019-07-21T00:00:00.000-0400
# 598928  2019-07-22T00:00:00.000-0400
# 599433  2019-07-23T00:00:00.000-0400
# 599447  2019-07-23T00:00:00.000-0400
# 599475  2019-07-23T00:00:00.000-0400
# 599481  2019-07-23T00:00:00.000-0400
# 600913  2019-07-26T00:00:00.000-0400
# 600942  2019-07-26T00:00:00.000-0400
# 600957  2019-07-26T00:00:00.000-0400
# 600970  2019-07-26T00:00:00.000-0400
# 601953  2019-07-28T00:00:00.000-0400
# 601956  2019-07-28T00:00:00.000-0400
# 602500  2019-07-29T00:00:00.000-0400
# 604742  2019-08-03T00:00:00.000-0400
# 605271  2019-08-04T00:00:00.000-0400
# 605316  2019-08-04T00:00:00.000-0400
# 605331  2019-08-04T00:00:00.000-0400
# 606467  2019-08-06T00:00:00.000-0400
# 606488  2019-08-06T00:00:00.000-0400
# 608769  2019-08-11T00:00:00.000-0400
# 608775  2019-08-11T00:00:00.000-0400
# 609746  2019-08-13T00:00:00.000-0400
# 609767  2019-08-13T00:00:00.000-0400
# 609770  2019-08-13T00:00:00.000-0400
# 609785  2019-08-13T00:00:00.000-0400
# 611180  2019-08-16T00:00:00.000-0400
# 611195  2019-08-16T00:00:00.000-0400
# 611724  2019-08-17T00:00:00.000-0400
#
#                                               metric_name  metric_value
# 25                      google.accounts:total_quota_in_mb        -63989
# 274                     google.accounts:total_quota_in_mb        -64049
# 523                     google.accounts:total_quota_in_mb        -64115
# 772                     google.accounts:total_quota_in_mb        -64154
# 1021                    google.accounts:total_quota_in_mb        -64174
# 1270                    google.accounts:total_quota_in_mb        -64204
# 1519                    google.accounts:total_quota_in_mb        -64230
# 1768                    google.accounts:total_quota_in_mb        -64287
# 2017                    google.accounts:total_quota_in_mb        -64336
# 2266                    google.accounts:total_quota_in_mb        -64395
# 2515                    google.accounts:total_quota_in_mb        -64439
# 2764                    google.accounts:total_quota_in_mb        -64463
# 3014                    google.accounts:total_quota_in_mb        -64487
# 3264                    google.accounts:total_quota_in_mb        -64512
# 3514                    google.accounts:total_quota_in_mb        -64567
# 3764                    google.accounts:total_quota_in_mb        -64612
# 4014                    google.accounts:total_quota_in_mb        -64677
# 4264                    google.accounts:total_quota_in_mb        -64746
# 4514                    google.accounts:total_quota_in_mb        -64812
# 4764                    google.accounts:total_quota_in_mb        -64850
# 5014                    google.accounts:total_quota_in_mb        -64877
# 5264                    google.accounts:total_quota_in_mb        -64940
# 5514                    google.accounts:total_quota_in_mb        -65014
# 5764                    google.accounts:total_quota_in_mb        -65074
# 6014                    google.accounts:total_quota_in_mb        -65114
# 6264                    google.accounts:total_quota_in_mb        -65152
# 6514                    google.accounts:total_quota_in_mb        -65173
# 6764                    google.accounts:total_quota_in_mb        -65212
# 7014                    google.accounts:total_quota_in_mb        -65268
# 194751  google.drive:num_owned_items_with_visibility_a...            -7
# ...                                                   ...           ...
# 592241  google.drive:num_owned_items_with_visibility_a...           -15
# 592821  google.drive:num_owned_items_with_visibility_p...           -38
# 598342  google.drive:num_owned_items_with_visibility_s...           -14
# 598928  google.drive:num_owned_items_with_visibility_s...         -8444
# 599433       google.drive:num_owned_google_drawings_delta            -1
# 599447  google.drive:num_owned_google_presentations_delta            -1
# 599475  google.drive:num_owned_items_with_visibility_a...           -21
# 599481  google.drive:num_owned_items_with_visibility_a...         -8906
# 600913          google.drive:num_owned_google_forms_delta            -9
# 600942                 google.drive:num_owned_items_delta         -4740
# 600957  google.drive:num_owned_items_with_visibility_p...         -5703
# 600970           google.drive:num_owned_other_types_delta         -4972
# 601953  google.drive:num_owned_items_with_visibility_a...           -91
# 601956  google.drive:num_owned_items_with_visibility_a...          -256
# 602500       google.drive:num_owned_google_drawings_delta            -1
# 604742  google.drive:num_owned_items_with_visibility_s...           -25
# 605271       google.drive:num_owned_google_drawings_delta            -1
# 605316  google.drive:num_owned_items_with_visibility_a...           -12
# 605331  google.drive:num_owned_items_with_visibility_s...            -4
# 606467          google.drive:num_owned_google_sites_delta            -1
# 606488  google.drive:num_owned_items_with_visibility_a...          -102
# 608769  google.drive:num_owned_items_with_visibility_p...           -14
# 608775  google.drive:num_owned_items_with_visibility_s...          -202
# 609746          google.drive:num_owned_google_sites_delta            -1
# 609767  google.drive:num_owned_items_with_visibility_a...          -209
# 609770  google.drive:num_owned_items_with_visibility_a...          -149
# 609785  google.drive:num_owned_items_with_visibility_s...          -791
# 611180  google.drive:num_owned_items_with_visibility_a...          -354
# 611195  google.drive:num_owned_items_with_visibility_s...         -6304
# 611724       google.drive:num_owned_google_drawings_delta            -1
#
# [879 rows x 3 columns]

# %% [markdown]
# No of values for a particular data, it is like how many times a particular metric_name is repeated.

# %%
metric_names_counts= df['metric_name'].value_counts()
metric_names_counts
# Out:
# google.docs:num_1day_active_users                                     1585
# google.gmail:num_inbound_rejected_emails                              1584
# google.gmail:num_inbound_spam_emails                                  1584
# google.gmail:num_outbound_rerouted_emails                             1584
# google.gmail:num_inbound_non_spam_emails                              1584
# google.gmail:num_inbound_rerouted_emails                              1584
# google.gmail:num_outbound_delivered_emails                            1584
# google.gmail:num_outbound_rejected_emails                             1584
# google.gmail:num_outbound_unencrypted_emails                          1584
# google.gmail:num_outbound_encrypted_emails                            1584
# google.gmail:num_inbound_encrypted_emails                             1584
# google.docs:num_7day_active_users                                     1584
# google.docs:num_30day_active_users                                    1584
# google.gmail:num_inbound_delivered_emails                             1584
# google.gmail:num_inbound_unencrypted_emails                           1584
# google.accounts:num_users                                             1577
# google.accounts:num_users_2sv_not_enrolled                            1577
# google.gmail:num_30day_imap_users                                     1577
# google.accounts:used_quota_in_mb                                      1577
# google.accounts:gmail_used_quota_in_mb                                1577
# google.gmail:num_emails_exchanged                                     1577
# google.accounts:num_7day_logins                                       1577
# google.gmail:num_7day_imap_users                                      1577
# google.accounts:num_users_2sv_not_enforced                            1577
# google.accounts:num_disabled_accounts                                 1577
# google.accounts:num_delegated_admins                                  1577
# google.accounts:num_locked_users                                      1577
# google.accounts:num_suspended_users                                   1577
# google.gmail:num_30day_pop_users                                      1577
# google.gmail:num_30day_webmail_users                                  1577
#                                                                       ...
# google.docs:num_docs_shared_outside_domain                             314
# google.device_management:num_30day_desktop_chrome_managed_devices      305
# google.device_management:num_7day_desktop_mac_managed_users            305
# google.device_management:num_30day_desktop_windows_managed_users       305
# google.device_management:num_30day_desktop_mac_managed_devices         305
# google.device_management:num_7day_desktop_chrome_managed_devices       305
# google.device_management:num_30day_desktop_linux_managed_devices       305
# google.device_management:num_7day_desktop_mac_managed_devices          305
# google.device_management:num_30day_desktop_chrome_managed_users        305
# google.device_management:num_30day_desktop_linux_managed_users         305
# google.device_management:num_30day_desktop_windows_managed_devices     305
# google.device_management:num_30day_desktop_mac_managed_users           305
# google.device_management:num_7day_desktop_windows_managed_users        305
# google.device_management:num_7day_desktop_linux_managed_devices        305
# google.device_management:num_7day_desktop_chrome_managed_users         305
# google.device_management:num_7day_desktop_windows_managed_devices      305
# google.device_management:num_7day_desktop_linux_managed_users          305
# google.device_management:num_1day_desktop_windows_managed_users        304
# google.device_management:num_1day_desktop_linux_managed_users          304
# google.device_management:num_1day_desktop_windows_managed_devices      304
# google.device_management:num_1day_desktop_chrome_managed_devices       304
# google.device_management:num_1day_desktop_chrome_managed_users         304
# google.device_management:num_1day_desktop_mac_managed_devices          304
# google.device_management:num_1day_desktop_mac_managed_users            304
# google.device_management:num_1day_desktop_linux_managed_devices        304
# google.cros:device_version_distribution                                234
# google.accounts:shared_drive_used_quota_in_mb                           55
# google.drive:num_owned_items_with_visibility_unknown_added               7
# google.drive:num_owned_items_with_visibility_unknown_delta               7
# google.drive:num_owned_items_with_visibility_unknown_removed             7
# Name: metric_name, Length: 649, dtype: int64

# %%
zero_users = df[df.metric_value==0]
zero_users
# Out:
#                                 time  \
# 0       2015-03-23T00:00:00.000-0400
# 1       2015-03-23T00:00:00.000-0400
# 2       2015-03-23T00:00:00.000-0400
# 3       2015-03-23T00:00:00.000-0400
# 17      2015-03-23T00:00:00.000-0400
# 18      2015-03-23T00:00:00.000-0400
# 19      2015-03-23T00:00:00.000-0400
# 23      2015-03-23T00:00:00.000-0400
# 24      2015-03-23T00:00:00.000-0400
# 27      2015-03-23T00:00:00.000-0400
# 31      2015-03-23T00:00:00.000-0400
# 32      2015-03-23T00:00:00.000-0400
# 33      2015-03-23T00:00:00.000-0400
# 34      2015-03-23T00:00:00.000-0400
# 35      2015-03-23T00:00:00.000-0400
# 36      2015-03-23T00:00:00.000-0400
# 37      2015-03-23T00:00:00.000-0400
# 38      2015-03-23T00:00:00.000-0400
# 39      2015-03-23T00:00:00.000-0400
# 40      2015-03-23T00:00:00.000-0400
# 41      2015-03-23T00:00:00.000-0400
# 42      2015-03-23T00:00:00.000-0400
# 43      2015-03-23T00:00:00.000-0400
# 44      2015-03-23T00:00:00.000-0400
# 45      2015-03-23T00:00:00.000-0400
# 46      2015-03-23T00:00:00.000-0400
# 47      2015-03-23T00:00:00.000-0400
# 48      2015-03-23T00:00:00.000-0400
# 49      2015-03-23T00:00:00.000-0400
# 50      2015-03-23T00:00:00.000-0400
# ...                              ...
# 611882  2019-08-17T00:00:00.000-0400
# 611883  2019-08-17T00:00:00.000-0400
# 611884  2019-08-17T00:00:00.000-0400
# 611885  2019-08-17T00:00:00.000-0400
# 611886  2019-08-17T00:00:00.000-0400
# 611887  2019-08-17T00:00:00.000-0400
# 611888  2019-08-17T00:00:00.000-0400
# 611889  2019-08-17T00:00:00.000-0400
# 611890  2019-08-17T00:00:00.000-0400
# 611891  2019-08-17T00:00:00.000-0400
# 611892  2019-08-17T00:00:00.000-0400
# 611893  2019-08-17T00:00:00.000-0400
# 611894  2019-08-17T00:00:00.000-0400
# 611895  2019-08-17T00:00:00.000-0400
# 611896  2019-08-17T00:00:00.000-0400
# 611897  2019-08-17T00:00:00.000-0400
# 611898  2019-08-17T00:00:00.000-0400
# 611899  2019-08-17T00:00:00.000-0400
# 611900  2019-08-17T00:00:00.000-0400
# 611901  2019-08-17T00:00:00.000-0400
# 611902  2019-08-17T00:00:00.000-0400
# 611903  2019-08-17T00:00:00.000-0400
# 611904  2019-08-17T00:00:00.000-0400
# 611905  2019-08-17T00:00:00.000-0400
# 611906  2019-08-17T00:00:00.000-0400
# 611907  2019-08-17T00:00:00.000-0400
# 611908  2019-08-17T00:00:00.000-0400
# 611909  2019-08-17T00:00:00.000-0400
# 611910  2019-08-17T00:00:00.000-0400
# 611912  2019-08-17T00:00:00.000-0400
#
#                                               metric_name  metric_value
# 0                     google.accounts:apps_total_licenses             0
# 1                      google.accounts:apps_used_licenses             0
# 2                         google.accounts:authorized_apps             0
# 3               google.accounts:coordinate_total_licenses             0
# 17                 google.accounts:num_users_2sv_enforced             0
# 18                 google.accounts:num_users_2sv_enrolled             0
# 19      google.accounts:num_users_2sv_enrolled_and_enf...             0
# 23      google.accounts:num_users_2sv_not_enrolled_but...             0
# 24      google.accounts:num_users_used_quota_lt_50percent             0
# 27                   google.accounts:vault_total_licenses             0
# 31      google.device_management:num_1day_android_2_1_...             0
# 32      google.device_management:num_1day_android_2_1_...             0
# 33      google.device_management:num_1day_android_2_2_...             0
# 34      google.device_management:num_1day_android_2_2_...             0
# 35      google.device_management:num_1day_android_2_3_...             0
# 36      google.device_management:num_1day_android_2_3_...             0
# 37      google.device_management:num_1day_android_2_4_...             0
# 38      google.device_management:num_1day_android_2_4_...             0
# 39      google.device_management:num_1day_android_3_0_...             0
# 40      google.device_management:num_1day_android_3_0_...             0
# 41      google.device_management:num_1day_android_3_1_...             0
# 42      google.device_management:num_1day_android_3_1_...             0
# 43      google.device_management:num_1day_android_3_2_...             0
# 44      google.device_management:num_1day_android_3_2_...             0
# 45      google.device_management:num_1day_android_4_0_...             0
# 46      google.device_management:num_1day_android_4_0_...             0
# 47      google.device_management:num_1day_android_4_1_...             0
# 48      google.device_management:num_1day_android_4_1_...             0
# 49      google.device_management:num_1day_android_4_2_...             0
# 50      google.device_management:num_1day_android_4_2_...             0
# ...                                                   ...           ...
# 611882                   google.meet:num_meetings_android             0
# 611883                google.meet:num_meetings_chromebase             0
# 611884                 google.meet:num_meetings_chromebox             0
# 611885                       google.meet:num_meetings_ios             0
# 611886                  google.meet:num_meetings_jamboard             0
# 611887            google.meet:num_meetings_unknown_client             0
# 611888                       google.meet:num_meetings_web             0
# 611889       google.meet:num_meetings_with_11_to_15_calls             0
# 611890       google.meet:num_meetings_with_16_to_25_calls             0
# 611891              google.meet:num_meetings_with_2_calls             0
# 611892       google.meet:num_meetings_with_26_to_50_calls             0
# 611893         google.meet:num_meetings_with_3_to_5_calls             0
# 611894        google.meet:num_meetings_with_6_to_10_calls             0
# 611895       google.meet:num_meetings_with_external_users             0
# 611896        google.meet:num_meetings_with_pstn_in_users             0
# 611897       google.meet:num_meetings_with_pstn_out_users             0
# 611898                     google.meet:total_call_minutes             0
# 611899             google.meet:total_call_minutes_android             0
# 611900   google.meet:total_call_minutes_by_external_users             0
# 611901   google.meet:total_call_minutes_by_internal_users             0
# 611902    google.meet:total_call_minutes_by_pstn_in_users             0
# 611903   google.meet:total_call_minutes_by_pstn_out_users             0
# 611904          google.meet:total_call_minutes_chromebase             0
# 611905           google.meet:total_call_minutes_chromebox             0
# 611906                 google.meet:total_call_minutes_ios             0
# 611907            google.meet:total_call_minutes_jamboard             0
# 611908      google.meet:total_call_minutes_unknown_client             0
# 611909                 google.meet:total_call_minutes_web             0
# 611910                  google.meet:total_meeting_minutes             0
# 611912                     google.sites:num_sites_created             0
#
# [347724 rows x 3 columns]

# %%
df.metric_value.max()
# Out:
# 274032962

# %%
df.loc[df['metric_name'] =='google.accounts:authorized_apps']
# Out:
#                                 time                      metric_name  \
# 2       2015-03-23T00:00:00.000-0400  google.accounts:authorized_apps
# 251     2015-03-24T00:00:00.000-0400  google.accounts:authorized_apps
# 500     2015-03-25T00:00:00.000-0400  google.accounts:authorized_apps
# 749     2015-03-26T00:00:00.000-0400  google.accounts:authorized_apps
# 998     2015-03-27T00:00:00.000-0400  google.accounts:authorized_apps
# 1247    2015-03-28T00:00:00.000-0400  google.accounts:authorized_apps
# 1496    2015-03-29T00:00:00.000-0400  google.accounts:authorized_apps
# 1745    2015-03-30T00:00:00.000-0400  google.accounts:authorized_apps
# 1994    2015-03-31T00:00:00.000-0400  google.accounts:authorized_apps
# 2243    2015-04-01T00:00:00.000-0400  google.accounts:authorized_apps
# 2492    2015-04-02T00:00:00.000-0400  google.accounts:authorized_apps
# 2741    2015-04-03T00:00:00.000-0400  google.accounts:authorized_apps
# 2990    2015-04-04T00:00:00.000-0400  google.accounts:authorized_apps
# 3240    2015-04-05T00:00:00.000-0400  google.accounts:authorized_apps
# 3490    2015-04-06T00:00:00.000-0400  google.accounts:authorized_apps
# 3740    2015-04-07T00:00:00.000-0400  google.accounts:authorized_apps
# 3990    2015-04-08T00:00:00.000-0400  google.accounts:authorized_apps
# 4240    2015-04-09T00:00:00.000-0400  google.accounts:authorized_apps
# 4490    2015-04-10T00:00:00.000-0400  google.accounts:authorized_apps
# 4740    2015-04-11T00:00:00.000-0400  google.accounts:authorized_apps
# 4990    2015-04-12T00:00:00.000-0400  google.accounts:authorized_apps
# 5240    2015-04-13T00:00:00.000-0400  google.accounts:authorized_apps
# 5490    2015-04-14T00:00:00.000-0400  google.accounts:authorized_apps
# 5740    2015-04-15T00:00:00.000-0400  google.accounts:authorized_apps
# 5990    2015-04-16T00:00:00.000-0400  google.accounts:authorized_apps
# 6240    2015-04-17T00:00:00.000-0400  google.accounts:authorized_apps
# 6490    2015-04-18T00:00:00.000-0400  google.accounts:authorized_apps
# 6740    2015-04-19T00:00:00.000-0400  google.accounts:authorized_apps
# 6990    2015-04-20T00:00:00.000-0400  google.accounts:authorized_apps
# 7240    2015-04-21T00:00:00.000-0400  google.accounts:authorized_apps
# ...                              ...                              ...
# 595798  2019-07-16T00:00:00.000-0400  google.accounts:authorized_apps
# 596216  2019-07-17T00:00:00.000-0400  google.accounts:authorized_apps
# 596625  2019-07-18T00:00:00.000-0400  google.accounts:authorized_apps
# 597046  2019-07-19T00:00:00.000-0400  google.accounts:authorized_apps
# 597467  2019-07-20T00:00:00.000-0400  google.accounts:authorized_apps
# 597888  2019-07-21T00:00:00.000-0400  google.accounts:authorized_apps
# 598474  2019-07-22T00:00:00.000-0400  google.accounts:authorized_apps
# 599918  2019-07-25T00:00:00.000-0400  google.accounts:authorized_apps
# 600507  2019-07-26T00:00:00.000-0400  google.accounts:authorized_apps
# 601095  2019-07-27T00:00:00.000-0400  google.accounts:authorized_apps
# 601515  2019-07-28T00:00:00.000-0400  google.accounts:authorized_apps
# 602100  2019-07-29T00:00:00.000-0400  google.accounts:authorized_apps
# 602689  2019-07-30T00:00:00.000-0400  google.accounts:authorized_apps
# 603275  2019-07-31T00:00:00.000-0400  google.accounts:authorized_apps
# 603693  2019-08-02T00:00:00.000-0400  google.accounts:authorized_apps
# 604282  2019-08-03T00:00:00.000-0400  google.accounts:authorized_apps
# 604871  2019-08-04T00:00:00.000-0400  google.accounts:authorized_apps
# 605460  2019-08-05T00:00:00.000-0400  google.accounts:authorized_apps
# 606046  2019-08-06T00:00:00.000-0400  google.accounts:authorized_apps
# 606635  2019-08-07T00:00:00.000-0400  google.accounts:authorized_apps
# 607056  2019-08-08T00:00:00.000-0400  google.accounts:authorized_apps
# 607477  2019-08-09T00:00:00.000-0400  google.accounts:authorized_apps
# 607898  2019-08-10T00:00:00.000-0400  google.accounts:authorized_apps
# 608315  2019-08-11T00:00:00.000-0400  google.accounts:authorized_apps
# 608904  2019-08-12T00:00:00.000-0400  google.accounts:authorized_apps
# 609325  2019-08-13T00:00:00.000-0400  google.accounts:authorized_apps
# 609914  2019-08-14T00:00:00.000-0400  google.accounts:authorized_apps
# 610317  2019-08-15T00:00:00.000-0400  google.accounts:authorized_apps
# 610735  2019-08-16T00:00:00.000-0400  google.accounts:authorized_apps
# 611324  2019-08-17T00:00:00.000-0400  google.accounts:authorized_apps
#
#         metric_value
# 2                  0
# 251                0
# 500                0
# 749                0
# 998                0
# 1247               0
# 1496               0
# 1745               0
# 1994               0
# 2243               0
# 2492               0
# 2741               0
# 2990               0
# 3240               0
# 3490               0
# 3740               0
# 3990               0
# 4240               0
# 4490               0
# 4740               0
# 4990               0
# 5240               0
# 5490               0
# 5740               0
# 5990               0
# 6240               0
# 6490               0
# 6740               0
# 6990               0
# 7240               0
# ...              ...
# 595798             0
# 596216             0
# 596625             0
# 597046             0
# 597467             0
# 597888             0
# 598474             0
# 599918             0
# 600507             0
# 601095             0
# 601515             0
# 602100             0
# 602689             0
# 603275             0
# 603693             0
# 604282             0
# 604871             0
# 605460             0
# 606046             0
# 606635             0
# 607056             0
# 607477             0
# 607898             0
# 608315             0
# 608904             0
# 609325             0
# 609914             0
# 610317             0
# 610735             0
# 611324             0
#
# [1542 rows x 3 columns]

# %%
for g in data.groupby(['metric_name']):
    print (g)

# %%
print(data[data.notnull()==1])
